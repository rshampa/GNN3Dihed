# %% [markdown]
# ## Know your libraries (KYL)

# %%
from dataset import QM9Dataset,LogSDataset,LogPDataset,FreeSolvDataset,ESOLDataset
from dataset import *
import numpy as np
import pandas as pd
from utils import *
import torch
from scipy.stats import pearsonr
from tqdm import tqdm
from model import Autoencoder # Simply importing the autoencoder model module from the model.py file
from model import GNN3D

import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import MolsToGridImage

import os
import sys
datadir="../data/esol/"
modeldir="./models/esol/"
# Create datadir and modeldir folders if they don't exist
if not os.path.exists(datadir):
    os.makedirs(datadir)
    
if not os.path.exists(modeldir):
    os.makedirs(modeldir)
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Split your dataset (SYD)

# %%
# Load dataset from CSV
dataset = pd.read_csv(datadir+"esol.csv")

# Split dataset into train and test
train_dataset, test_dataset = split_dataset(dataset, 0.8)

# Write train_dataset and test_dataset to CSV files
train_dataset.to_csv(datadir+"train.csv", index=False)
test_dataset.to_csv(datadir+"test.csv", index=False)

print("Train and test datasets saved successfully.")
# Out:
# Train and test datasets saved successfully.

# %% [markdown]
# ## Process your data (PYD)

# %%
train_samples = LogPDataset(datadir+"train")
print(train_samples)
print("===================================")
test_samples = LogPDataset(datadir+"test")
print(test_samples)
# Out:
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: LogP
# Number of Molecules Loaded: 902
# ===================================
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: LogP
# Number of Molecules Loaded: 226

# %% [markdown]
# ## Know your featues (KYF)

# %%
# Printing out the dimensions of all of these features with a description of what each feature is
print(f"Atomic Features: {(train_samples[0])[0].shape} - This represents the atomic features of the molecule")
print(f"Bond Features: {(train_samples[0])[1].shape} - This represents the bond features of the molecule")
print(f"Angle Features: {(train_samples[0])[2].shape} - This represents the angle features of the molecule")
print(f"Dihedral Features: {(train_samples[0])[3].shape} - This represents the dihedral features of the molecule")
print(f"Global Molecular Features: {(train_samples[0])[4].shape} - This represents the global molecular features of the molecule")
print(f"Bond Indices: {(train_samples[0])[5].shape} - This represents the bond indices of the molecule")
print(f"Angle Indices: {(train_samples[0])[6].shape} - This represents the angle indices of the molecule")
print(f"Dihedral Indices: {(train_samples[0])[7].shape} - This represents the dihedral indices of the molecule")
print(f"Target: {(train_samples[0])[8].shape} - This represents the target of the molecule")
# Out:
# Atomic Features: torch.Size([10, 56]) - This represents the atomic features of the molecule
# Bond Features: torch.Size([20, 10]) - This represents the bond features of the molecule
# Angle Features: torch.Size([28]) - This represents the angle features of the molecule
# Dihedral Features: torch.Size([32]) - This represents the dihedral features of the molecule
# Global Molecular Features: torch.Size([200]) - This represents the global molecular features of the molecule
# Bond Indices: torch.Size([20, 2]) - This represents the bond indices of the molecule
# Angle Indices: torch.Size([28, 2]) - This represents the angle indices of the molecule
# Dihedral Indices: torch.Size([32, 2]) - This represents the dihedral indices of the molecule
# Target: torch.Size([1]) - This represents the target of the molecule

# %% [markdown]
# ## Know your modules (KYM)

# %%
def train_autoencoder_model(samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train Autoencoder: Atom and bond"""
    # Set the model in training mode
    atom_autoencoder.train()
    bond_autoencoder.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)

    # Lists to store losses
    avg_atom_rmse_losses = []
    avg_bond_rmse_losses = []

    for epoch_i in range(n_epochs):
        avg_atom_rmse_loss = 0
        avg_bond_rmse_loss = 0
        total_samples = 0
        
        for i, molecule in enumerate(samples):
            atom_features = molecule[0].to(device)
            bond_features = molecule[1].to(device)
            
            # Forward pass
            atom_features_reconstructed = atom_autoencoder(atom_features)
            bond_features_reconstructed = bond_autoencoder(bond_features)
            
            # Calculating loss
            atom_loss = mse_loss_fn(atom_features_reconstructed, atom_features)
            bond_loss = mse_loss_fn(bond_features_reconstructed, bond_features)
            
            # Backward pass and optimization step
            atom_optimizer.zero_grad()
            bond_optimizer.zero_grad()
            atom_loss.backward()
            bond_loss.backward()
            atom_optimizer.step()
            bond_optimizer.step()
            
            # Calculating average loss
            avg_atom_rmse_loss = (avg_atom_rmse_loss * total_samples + torch.sqrt(atom_loss).item()) / (total_samples + 1)
            avg_bond_rmse_loss = (avg_bond_rmse_loss * total_samples + torch.sqrt(bond_loss).item()) / (total_samples + 1)           
            total_samples += 1

            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i + 1:>3}/{n_epochs} | Samples: {i + 1:>6}/{len(samples)} | Atom Avg. RMSE Loss: {avg_atom_rmse_loss:.4f} | Bond Avg. RMSE Loss: {avg_bond_rmse_loss:.4f}")
        
        # Append average losses for the epoch to lists
        avg_atom_rmse_losses.append(avg_atom_rmse_loss)
        avg_bond_rmse_losses.append(avg_bond_rmse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"autoencoder_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg Atom RMSE Loss\tAvg Bond RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i+1}\t{avg_atom_rmse_losses[epoch_i]}\t{avg_bond_rmse_losses[epoch_i]}\n")

    # Save model state
    torch.save(atom_autoencoder.state_dict(), f"{save_dir}atom_autoencoder_{dataset_name}.pth")
    torch.save(bond_autoencoder.state_dict(), f"{save_dir}bond_autoencoder_{dataset_name}.pth")
    
    return avg_atom_rmse_losses, avg_bond_rmse_losses
    



def process_molecule(molecule, atom_autoencoder, bond_autoencoder):
    """Separate input features and target"""
    # Ensure molecule has at least 8 elements
    if len(molecule) < 8:
        return None, None
    
    target = molecule[8].to(device)  # Assuming target is the 9th element (index 8)
    # Assuming first 8 elements are molecule graph input features:
    # atomic_features, bond_features, angle_features, dihedral_features, 
    # global_molecular_features, bond_indices, angle_indices,  dihedral_indices    
    molecule_data = [mol_elem.to(device) for mol_elem in molecule[:8]]
    
    # Putting latent atomic and bond features through encoders
    molecule_data[0] = atom_autoencoder.encode(molecule_data[0])
    molecule_data[1] = bond_autoencoder.encode(molecule_data[1])
    
    return molecule_data, target




def train_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train GNN3D"""
    # Set the model in training mode
    gnn3d.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)
   
    # Lists to store losses
    avg_rmse_losses = []
    avg_mse_losses = []

    for epoch_i in range(n_epochs):
        avg_rmse_loss = 0
        avg_mse_loss = 0
        total_samples = 0
        
        for i in tqdm(range(len(samples)), desc='Processing samples'):
            molecule_data, target = process_molecule(samples[i], atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)
            
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            
            # Backward pass
            gnn_optimizer.zero_grad()
            loss.backward()
            gnn_optimizer.step()
            
            # Calculating average loss
            avg_rmse_loss = (avg_rmse_loss * total_samples + torch.sqrt(loss).item()) / (total_samples + 1)
            avg_mse_loss = (avg_mse_loss * total_samples + loss.item()) / (total_samples + 1)
            total_samples += 1
            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3} | Samples: {i:>6}/{len(samples)} | Avg. RMSE Loss: {avg_rmse_loss:.4f} | Avg. MSE Loss: {avg_mse_loss:.4f}")

                # Append average losses for the epoch to lists
        avg_rmse_losses.append(avg_rmse_loss)
        avg_mse_losses.append(avg_mse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"gnn3d_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg RMSE Loss\tAvg RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i+1}\t{avg_rmse_losses[epoch_i]}\t{avg_mse_losses[epoch_i]}\n")

    # Save model state
    torch.save(gnn3d.state_dict(), f"{save_dir}gnn3d_{dataset_name}.pth")
    
    return avg_rmse_losses, avg_mse_losses




def evaluate_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder):
    """Evaluate GNN3D"""
    # Set the model in evaluation mode
    gnn3d.eval()

    avg_rmse_loss = 0
    avg_mse_loss = 0
    total_samples = 0
    
    with torch.no_grad():
        for i, molecule in enumerate(samples):
            molecule_data, target = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)
            
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            
            # Accumulate losses
            avg_rmse_loss += (torch.sqrt(loss).item())
            avg_mse_loss += loss.item()
            total_samples += 1
    
    # Calculate average losses
    avg_rmse_loss /= total_samples
    avg_mse_loss /= total_samples
    
    print(f"Evaluation Results:")
    print(f"Avg. RMSE Loss: {avg_rmse_loss:.4f}")
    print(f"Avg. MSE Loss: {avg_mse_loss:.4f}")
    
    return avg_rmse_loss, avg_mse_loss

# %% [markdown]
# ## Training

# %% [markdown]
# ### Autoencoder training

# %%
atom_autoencoder = Autoencoder(56, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
atom_optimizer = torch.optim.Adam(atom_autoencoder.parameters())
bond_optimizer = torch.optim.Adam(bond_autoencoder.parameters())

atom_losses, bond_losses = train_autoencoder_model(train_samples, atom_autoencoder, bond_autoencoder, n_epochs=20, printstep=500, save_dir=modeldir, dataset_name="logp")
# Out:
# Epoch:   1/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.3669 | Bond Avg. RMSE Loss: 0.5746
# Epoch:   1/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.1726 | Bond Avg. RMSE Loss: 0.3415
# Epoch:   2/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0732 | Bond Avg. RMSE Loss: 0.0887
# Epoch:   2/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0604 | Bond Avg. RMSE Loss: 0.1026
# Epoch:   3/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0517 | Bond Avg. RMSE Loss: 0.0819
# Epoch:   3/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0515 | Bond Avg. RMSE Loss: 0.0953
# Epoch:   4/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0492 | Bond Avg. RMSE Loss: 0.0739
# Epoch:   4/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0483 | Bond Avg. RMSE Loss: 0.0888
# Epoch:   5/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0470 | Bond Avg. RMSE Loss: 0.0722
# Epoch:   5/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0461 | Bond Avg. RMSE Loss: 0.0784
# Epoch:   6/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0450 | Bond Avg. RMSE Loss: 0.0563
# Epoch:   6/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0444 | Bond Avg. RMSE Loss: 0.0477
# Epoch:   7/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0446 | Bond Avg. RMSE Loss: 0.0302
# Epoch:   7/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0433 | Bond Avg. RMSE Loss: 0.0319
# Epoch:   8/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0435 | Bond Avg. RMSE Loss: 0.0208
# Epoch:   8/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0426 | Bond Avg. RMSE Loss: 0.0262
# Epoch:   9/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0417 | Bond Avg. RMSE Loss: 0.0180
# Epoch:   9/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0410 | Bond Avg. RMSE Loss: 0.0221
# Epoch:  10/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0420 | Bond Avg. RMSE Loss: 0.0166
# Epoch:  10/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0413 | Bond Avg. RMSE Loss: 0.0198
# Epoch:  11/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0403 | Bond Avg. RMSE Loss: 0.0164
# Epoch:  11/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0402 | Bond Avg. RMSE Loss: 0.0173
# Epoch:  12/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0404 | Bond Avg. RMSE Loss: 0.0131
# Epoch:  12/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0402 | Bond Avg. RMSE Loss: 0.0152
# Epoch:  13/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0388 | Bond Avg. RMSE Loss: 0.0080
# Epoch:  13/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0397 | Bond Avg. RMSE Loss: 0.0136
# Epoch:  14/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0389 | Bond Avg. RMSE Loss: 0.0113
# Epoch:  14/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0396 | Bond Avg. RMSE Loss: 0.0134
# Epoch:  15/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0378 | Bond Avg. RMSE Loss: 0.0055
# Epoch:  15/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0395 | Bond Avg. RMSE Loss: 0.0123
# Epoch:  16/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0372 | Bond Avg. RMSE Loss: 0.0067
# Epoch:  16/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0394 | Bond Avg. RMSE Loss: 0.0121
# Epoch:  17/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0378 | Bond Avg. RMSE Loss: 0.0048
# Epoch:  17/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0392 | Bond Avg. RMSE Loss: 0.0116
# Epoch:  18/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0366 | Bond Avg. RMSE Loss: 0.0058
# Epoch:  18/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0392 | Bond Avg. RMSE Loss: 0.0111
# Epoch:  19/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0381 | Bond Avg. RMSE Loss: 0.0041
# Epoch:  19/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0394 | Bond Avg. RMSE Loss: 0.0102
# Epoch:  20/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0386 | Bond Avg. RMSE Loss: 0.0044
# Epoch:  20/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0393 | Bond Avg. RMSE Loss: 0.0097

# %%
# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
#plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Atom Autoencoder Training Losses for logp")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}atom_autoencoder_losses_logp.png")
plt.show()

# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
#plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Bond Autoencoder Training Losses for logp")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}bond_autoencoder_losses_logp.png")
plt.show()

# %% [markdown]
# ### GNN3D training

# %%
atom_autoencoder = Autoencoder(56, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
gnn3d = GNN3D(atomic_vector_size=10, bond_vector_size=3, number_of_molecular_features=200, number_of_targets=1).to(device)
gnn_optimizer = torch.optim.Adam(gnn3d.parameters())
rmse_losses, mse_losses = train_gnn3d_model(gnn3d, train_samples, atom_autoencoder, bond_autoencoder, n_epochs=20, printstep=500, save_dir=modeldir, dataset_name="logp")
# Out:
# Processing samples:   0%|▎                                                                                                                                       | 2/902 [00:00<00:48, 18.39it/s]
# Epoch:   0 | Samples:      0/902 | Avg. RMSE Loss: 0.5291 | Avg. MSE Loss: 0.2799
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.55it/s]
# Epoch:   0 | Samples:    500/902 | Avg. RMSE Loss: 1.2128 | Avg. MSE Loss: 2.4245
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:11<00:00, 12.70it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:37, 23.74it/s]
# Epoch:   1 | Samples:      0/902 | Avg. RMSE Loss: 1.3625 | Avg. MSE Loss: 1.8564
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:29, 13.73it/s]
# Epoch:   1 | Samples:    500/902 | Avg. RMSE Loss: 0.7190 | Avg. MSE Loss: 0.8496
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.80it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.18it/s]
# Epoch:   2 | Samples:      0/902 | Avg. RMSE Loss: 1.3248 | Avg. MSE Loss: 1.7552
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:28, 13.84it/s]
# Epoch:   2 | Samples:    500/902 | Avg. RMSE Loss: 0.6086 | Avg. MSE Loss: 0.6156
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.81it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:37, 23.80it/s]
# Epoch:   3 | Samples:      0/902 | Avg. RMSE Loss: 1.2324 | Avg. MSE Loss: 1.5188
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:29, 13.65it/s]
# Epoch:   3 | Samples:    500/902 | Avg. RMSE Loss: 0.5543 | Avg. MSE Loss: 0.5120
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.78it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.29it/s]
# Epoch:   4 | Samples:      0/902 | Avg. RMSE Loss: 1.2916 | Avg. MSE Loss: 1.6682
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:29, 13.71it/s]
# Epoch:   4 | Samples:    500/902 | Avg. RMSE Loss: 0.5183 | Avg. MSE Loss: 0.4501
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.81it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:39, 22.62it/s]
# Epoch:   5 | Samples:      0/902 | Avg. RMSE Loss: 1.2550 | Avg. MSE Loss: 1.5749
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:29, 13.71it/s]
# Epoch:   5 | Samples:    500/902 | Avg. RMSE Loss: 0.4924 | Avg. MSE Loss: 0.4102
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.80it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:39, 22.96it/s]
# Epoch:   6 | Samples:      0/902 | Avg. RMSE Loss: 1.2757 | Avg. MSE Loss: 1.6275
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:29, 13.67it/s]
# Epoch:   6 | Samples:    500/902 | Avg. RMSE Loss: 0.4697 | Avg. MSE Loss: 0.3744
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.80it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:39, 22.93it/s]
# Epoch:   7 | Samples:      0/902 | Avg. RMSE Loss: 1.2705 | Avg. MSE Loss: 1.6143
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:29, 13.71it/s]
# Epoch:   7 | Samples:    500/902 | Avg. RMSE Loss: 0.4560 | Avg. MSE Loss: 0.3531
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.72it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:39, 22.81it/s]
# Epoch:   8 | Samples:      0/902 | Avg. RMSE Loss: 1.2526 | Avg. MSE Loss: 1.5690
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.39it/s]
# Epoch:   8 | Samples:    500/902 | Avg. RMSE Loss: 0.4382 | Avg. MSE Loss: 0.3289
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:11<00:00, 12.54it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:39, 22.77it/s]
# Epoch:   9 | Samples:      0/902 | Avg. RMSE Loss: 1.0775 | Avg. MSE Loss: 1.1609
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.64it/s]
# Epoch:   9 | Samples:    500/902 | Avg. RMSE Loss: 0.4233 | Avg. MSE Loss: 0.3085
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:11<00:00, 12.56it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:39, 22.87it/s]
# Epoch:  10 | Samples:      0/902 | Avg. RMSE Loss: 0.9733 | Avg. MSE Loss: 0.9472
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.72it/s]
# Epoch:  10 | Samples:    500/902 | Avg. RMSE Loss: 0.4114 | Avg. MSE Loss: 0.2923
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:10<00:00, 12.71it/s]
# Processing samples:   0%|▌                                                                                                                                       | 4/902 [00:00<00:55, 16.05it/s]
# Epoch:  11 | Samples:      0/902 | Avg. RMSE Loss: 0.8927 | Avg. MSE Loss: 0.7970
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.58it/s]
# Epoch:  11 | Samples:    500/902 | Avg. RMSE Loss: 0.3991 | Avg. MSE Loss: 0.2768
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:12<00:00, 12.49it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:39, 22.74it/s]
# Epoch:  12 | Samples:      0/902 | Avg. RMSE Loss: 0.7898 | Avg. MSE Loss: 0.6237
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.58it/s]
# Epoch:  12 | Samples:    500/902 | Avg. RMSE Loss: 0.3932 | Avg. MSE Loss: 0.2672
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:11<00:00, 12.65it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.31it/s]
# Epoch:  13 | Samples:      0/902 | Avg. RMSE Loss: 0.8462 | Avg. MSE Loss: 0.7160
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.62it/s]
# Epoch:  13 | Samples:    500/902 | Avg. RMSE Loss: 0.3846 | Avg. MSE Loss: 0.2540
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:12<00:00, 12.48it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.52it/s]
# Epoch:  14 | Samples:      0/902 | Avg. RMSE Loss: 0.7532 | Avg. MSE Loss: 0.5673
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:39<00:29, 13.56it/s]
# Epoch:  14 | Samples:    500/902 | Avg. RMSE Loss: 0.3746 | Avg. MSE Loss: 0.2421
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:11<00:00, 12.67it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.34it/s]
# Epoch:  15 | Samples:      0/902 | Avg. RMSE Loss: 0.6768 | Avg. MSE Loss: 0.4581
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.60it/s]
# Epoch:  15 | Samples:    500/902 | Avg. RMSE Loss: 0.3692 | Avg. MSE Loss: 0.2373
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:11<00:00, 12.62it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.26it/s]
# Epoch:  16 | Samples:      0/902 | Avg. RMSE Loss: 0.6387 | Avg. MSE Loss: 0.4080
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.44it/s]
# Epoch:  16 | Samples:    500/902 | Avg. RMSE Loss: 0.3621 | Avg. MSE Loss: 0.2276
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:12<00:00, 12.51it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.26it/s]
# Epoch:  17 | Samples:      0/902 | Avg. RMSE Loss: 0.5910 | Avg. MSE Loss: 0.3493
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:30, 13.27it/s]
# Epoch:  17 | Samples:    500/902 | Avg. RMSE Loss: 0.3557 | Avg. MSE Loss: 0.2193
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:12<00:00, 12.43it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:38, 23.45it/s]
# Epoch:  18 | Samples:      0/902 | Avg. RMSE Loss: 0.5553 | Avg. MSE Loss: 0.3084
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:30, 13.17it/s]
# Epoch:  18 | Samples:    500/902 | Avg. RMSE Loss: 0.3521 | Avg. MSE Loss: 0.2141
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:12<00:00, 12.46it/s]
# Processing samples:   0%|▍                                                                                                                                       | 3/902 [00:00<00:40, 22.01it/s]
# Epoch:  19 | Samples:      0/902 | Avg. RMSE Loss: 0.5251 | Avg. MSE Loss: 0.2757
# Processing samples:  56%|██████████████████████████████████████████████████████████████████████████▋                                                           | 503/902 [00:40<00:29, 13.55it/s]
# Epoch:  19 | Samples:    500/902 | Avg. RMSE Loss: 0.3445 | Avg. MSE Loss: 0.2076
# Processing samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 902/902 [01:11<00:00, 12.54it/s]

# %%
# Assuming rmse_losses is the list of RMSE losses obtained from training
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(rmse_losses)+1), rmse_losses, marker='o', linestyle='-', color='b', label='Avg. RMSE Loss')
plt.title(f"GNN3D Training Losses for logp")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}gnn3d_rmse_losses_logp.png")
plt.show()

# %% [markdown]
# ## Testing

# %%
evaluate_gnn3d_model(
    gnn3d, 
    test_samples, 
    atom_autoencoder, 
    bond_autoencoder
)
# Out:
# Evaluation Results:
# Avg. RMSE Loss: 0.4418
# Avg. MSE Loss: 0.3541
# (0.4417653082152911, 0.354149472702272)

# %% [markdown]
# ## Know your predictions (KYP)

# %%
def molecule_from_smiles(smiles):
    """Convert SMILES to rdkit.Mol with 2D coordinates"""
    molecule = Chem.MolFromSmiles(smiles, sanitize=False)
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        Chem.SanitizeMol(molecule, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ flag)

    Chem.AssignStereochemistry(molecule, cleanIt=True, force=True)
    return molecule

def smi2conf_etkdg(smiles):
    '''Convert SMILES to rdkit.Mol with 3D coordinates
       Use Experimental Torsion angles Knowledge-based Distance Geometry ETKDGv3
       method - version 3 (small rings)
       params.numThreads = 0 uses max no. of threads allowed on a conputer
    '''
    params = Chem.rdDistGeom.srETKDGv3()
    params.randomSeed = 12412
    params.clearConfs = True
    params.numThreads = 0
    
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        mol = Chem.AddHs(mol)
        AllChem.EmbedMolecule(mol)
        AllChem.EmbedMultipleConfs(mol, numConfs=500, params=params)
        
        return mol
    else:
        return None

# %% [markdown]
# ## Know your predictions (KYP)

# %%
# Set the model in evaluation mode
gnn3d.eval()

# List to store predictions
predictions = []
targets = []

# Iterate over test samples
for molecule in test_samples:
    # Assuming process_molecule function converts each molecule list to tensor
    molecule_data, target = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
    
    if molecule_data is None:
        continue  # Skip if molecule_data is None
    
    # Move molecule_data to device if necessary
    molecule_data = [elem.to(device) for elem in molecule_data]
    
    # Forward pass
    with torch.no_grad():
        prediction = gnn3d(molecule_data)
    
    # Extract prediction, assuming single scalar output prediction
    prediction_value = prediction.item()

    target_val = target.item()

    print(f"Target: {target.item():.4f} | Prediction: {prediction.item():.4f}")
    
    # Store prediction
    predictions.append(prediction_value)
    targets.append(target_val)
# Out:
# Target: -0.4500 | Prediction: -0.8773
# Target: -3.5400 | Prediction: -3.6948
# Target: -4.3600 | Prediction: -3.8358
# Target: -4.8100 | Prediction: -4.8726
# Target: -2.0000 | Prediction: -1.8120
# Target: -1.2900 | Prediction: -1.8010
# Target: -3.9000 | Prediction: -2.3347
# Target: -7.2500 | Prediction: -6.8999
# Target: -0.6670 | Prediction: -0.0855
# Target: 0.1000 | Prediction: 0.0140
# Target: -4.5220 | Prediction: -3.9694
# Target: -4.0970 | Prediction: -3.8328
# Target: -4.6300 | Prediction: -5.0395
# Target: -1.9950 | Prediction: -1.7037
# Target: -4.3800 | Prediction: -5.0403
# Target: -5.2330 | Prediction: -4.8780
# Target: -2.2530 | Prediction: -2.0909
# Target: -7.8700 | Prediction: -8.6911
# Target: -7.0100 | Prediction: -8.0057
# Target: -3.4830 | Prediction: -2.9204
# Target: -4.0700 | Prediction: -4.9570
# Target: -0.8500 | Prediction: -1.5379
# Target: -4.1100 | Prediction: -4.3188
# Target: -0.8200 | Prediction: -1.4188
# Target: -2.7700 | Prediction: -2.5604
# Target: -2.2200 | Prediction: -1.1316
# Target: 0.4800 | Prediction: 1.2735
# Target: -2.9600 | Prediction: -2.7974
# Target: -6.5900 | Prediction: -7.5719
# Target: -2.3500 | Prediction: -2.2378
# Target: -2.1540 | Prediction: -2.1394
# Target: -0.7200 | Prediction: -0.9655
# Target: -1.6550 | Prediction: -2.2885
# Target: -3.9300 | Prediction: -2.0867
# Target: -1.4600 | Prediction: -1.4273
# Target: -1.5200 | Prediction: -2.1515
# Target: -4.2300 | Prediction: -4.0121
# Target: -4.4110 | Prediction: -4.4776
# Target: -0.6240 | Prediction: -1.3505
# Target: -4.4400 | Prediction: -4.2350
# Target: -2.6920 | Prediction: -2.4866
# Target: -4.1600 | Prediction: -4.7963
# Target: -2.3300 | Prediction: -2.0563
# Target: -6.8600 | Prediction: -7.5058
# Target: -2.4300 | Prediction: -2.5628
# Target: -4.0990 | Prediction: -4.4766
# Target: -0.0920 | Prediction: -0.0492
# Target: -0.7000 | Prediction: -1.0276
# Target: -2.4600 | Prediction: -2.2994
# Target: -0.6200 | Prediction: -0.6793
# Target: -2.3500 | Prediction: -3.1802
# Target: -6.2000 | Prediction: -6.0362
# Target: -4.7060 | Prediction: -4.4488
# Target: -3.1100 | Prediction: -3.0149
# Target: -4.2860 | Prediction: -4.4579
# Target: -2.3100 | Prediction: -2.1803
# Target: 0.7900 | Prediction: -0.1780
# Target: -1.9100 | Prediction: -2.2746
# Target: -1.0600 | Prediction: -2.6376
# Target: -4.6300 | Prediction: -3.8965
# Target: -8.1720 | Prediction: -8.6091
# Target: -1.8000 | Prediction: -1.7154
# Target: -4.8600 | Prediction: -5.2093
# Target: -7.3200 | Prediction: -7.5148
# Target: -2.3200 | Prediction: -2.2285
# Target: -3.7600 | Prediction: -4.1808
# Target: -3.2900 | Prediction: -3.5994
# Target: -2.5400 | Prediction: -2.1304
# Target: -4.6790 | Prediction: -4.6391
# Target: -3.2000 | Prediction: -3.6042
# Target: -0.0200 | Prediction: 0.7886
# Target: -0.4600 | Prediction: -0.5202
# Target: -5.2800 | Prediction: -5.3507
# Target: -2.4400 | Prediction: -2.0575
# Target: 1.1200 | Prediction: 1.1635
# Target: -4.0000 | Prediction: -4.5476
# Target: -4.6400 | Prediction: -4.3803
# Target: -2.1500 | Prediction: -2.3629
# Target: -4.2000 | Prediction: -4.1153
# Target: -1.9000 | Prediction: -1.8308
# Target: -2.1200 | Prediction: -2.4813
# Target: -4.2900 | Prediction: -4.3028
# Target: -0.9800 | Prediction: -0.8965
# Target: -4.0200 | Prediction: -4.5657
# Target: -2.4780 | Prediction: -3.5722
# Target: -8.4020 | Prediction: -8.3591
# Target: -3.0100 | Prediction: -2.8706
# Target: -5.1900 | Prediction: -4.8195
# Target: -3.6700 | Prediction: -3.3280
# Target: -1.8500 | Prediction: -1.6804
# Target: -2.4600 | Prediction: -2.3984
# Target: -0.8200 | Prediction: -1.4875
# Target: -3.0830 | Prediction: -2.8271
# Target: -6.1400 | Prediction: -6.1479
# Target: -6.2370 | Prediction: -6.1897
# Target: -4.6300 | Prediction: -4.8556
# Target: -2.8500 | Prediction: -2.2626
# Target: -5.2300 | Prediction: -5.3377
# Target: -1.6300 | Prediction: -2.3497
# Target: -0.8000 | Prediction: -0.8022
# Target: -0.8540 | Prediction: -0.4329
# Target: -3.1710 | Prediction: -3.5470
# Target: -3.3640 | Prediction: -1.7605
# Target: -0.7000 | Prediction: -1.1534
# Target: 0.3200 | Prediction: 0.3267
# Target: -3.7850 | Prediction: -4.0502
# Target: -1.2200 | Prediction: -1.0694
# Target: -0.8760 | Prediction: -0.7037
# Target: 0.0000 | Prediction: -0.0294
# Target: -4.1300 | Prediction: -4.8753
# Target: -5.5300 | Prediction: -6.8625
# Target: -2.5700 | Prediction: -3.3291
# Target: -4.2400 | Prediction: -4.2570
# Target: -3.8000 | Prediction: -3.4981
# Target: -1.4700 | Prediction: -1.3731
# Target: 0.4300 | Prediction: 1.2022
# Target: -2.1800 | Prediction: -2.3537
# Target: -4.3000 | Prediction: -4.3714
# Target: -4.4300 | Prediction: -4.1802
# Target: -3.0210 | Prediction: -4.0770
# Target: -2.3400 | Prediction: -1.7748
# Target: -4.5300 | Prediction: -4.2546
# Target: -3.1800 | Prediction: -3.4215
# Target: -2.0000 | Prediction: -1.9071
# Target: -5.4300 | Prediction: -4.6183
# Target: -4.2900 | Prediction: -4.0683
# Target: -7.3200 | Prediction: -5.6188
# Target: -1.6400 | Prediction: -2.8802
# Target: -8.0170 | Prediction: -8.0066
# Target: -6.4700 | Prediction: -6.6934
# Target: -1.5200 | Prediction: -1.1252
# Target: -1.6000 | Prediction: -1.4686
# Target: -3.2200 | Prediction: -3.7284
# Target: -2.8310 | Prediction: -2.8739
# Target: -0.7200 | Prediction: -0.8474
# Target: -4.3800 | Prediction: -4.3692
# Target: -7.4200 | Prediction: -8.2890
# Target: -2.8400 | Prediction: -4.7953
# Target: -4.4600 | Prediction: -4.8687
# Target: -3.7500 | Prediction: -3.4203
# Target: -3.4300 | Prediction: -2.9727
# Target: -3.8100 | Prediction: -3.8554
# Target: -4.1500 | Prediction: -2.7207
# Target: -0.7400 | Prediction: -0.8434
# Target: -4.0000 | Prediction: -3.6283
# Target: -3.0000 | Prediction: -2.1887
# Target: -4.2300 | Prediction: -4.0498
# Target: 0.1060 | Prediction: -1.4045
# Target: -1.2400 | Prediction: -0.6412
# Target: -3.6400 | Prediction: -3.4145
# Target: -2.5180 | Prediction: -3.7094
# Target: -1.6000 | Prediction: -1.3401
# Target: -4.3140 | Prediction: -3.7027
# Target: -1.8500 | Prediction: -1.6794
# Target: -1.3400 | Prediction: -1.7435
# Target: -3.4600 | Prediction: -2.7859
# Target: 1.1000 | Prediction: 0.3337
# Target: -4.7490 | Prediction: -4.0938
# Target: -2.0900 | Prediction: -3.0390
# Target: -8.7100 | Prediction: -8.1935
# Target: -0.4100 | Prediction: -0.0957
# Target: -4.1140 | Prediction: -3.7764
# Target: -0.8900 | Prediction: -0.9874
# Target: -2.0000 | Prediction: -2.1640
# Target: -1.8860 | Prediction: -1.9661
# Target: -3.3300 | Prediction: -3.1727
# Target: -6.0100 | Prediction: -5.0305
# Target: -2.3220 | Prediction: -2.6651
# Target: -2.4000 | Prediction: -2.1092
# Target: -3.3700 | Prediction: -3.0323
# Target: -2.3900 | Prediction: -2.4851
# Target: -0.5100 | Prediction: -0.5669
# Target: -3.3700 | Prediction: -2.6716
# Target: 0.5700 | Prediction: 0.6733
# Target: -5.1700 | Prediction: -4.6758
# Target: -3.2700 | Prediction: -2.8261
# Target: -2.1300 | Prediction: -2.6637
# Target: -1.0000 | Prediction: -2.2560
# Target: -1.5200 | Prediction: -1.5469
# Target: -4.1900 | Prediction: -4.2114
# Target: -3.0900 | Prediction: -3.6617
# Target: -1.9400 | Prediction: -2.5333
# Target: -6.3010 | Prediction: -6.3122
# Target: -2.2900 | Prediction: -1.9513
# Target: -0.8000 | Prediction: -1.1425
# Target: 0.3000 | Prediction: -0.4364
# Target: -4.6340 | Prediction: -3.8603
# Target: -2.6400 | Prediction: -2.4400
# Target: -1.2300 | Prediction: -1.6728
# Target: -2.7300 | Prediction: -3.6475
# Target: -1.4880 | Prediction: -1.0670
# Target: -4.9200 | Prediction: -5.0904
# Target: -0.9200 | Prediction: -1.1139
# Target: -1.7300 | Prediction: -1.6279
# Target: -5.4600 | Prediction: -6.7734
# Target: -3.3000 | Prediction: -3.4380
# Target: -1.8400 | Prediction: -1.2846
# Target: 0.2900 | Prediction: 0.1435
# Target: -7.9200 | Prediction: -7.4315
# Target: -4.6780 | Prediction: -5.7120
# Target: -6.5600 | Prediction: -5.5735
# Target: -4.6500 | Prediction: -4.7909
# Target: -8.0030 | Prediction: -7.8306
# Target: -4.3100 | Prediction: -4.0742
# Target: -4.4000 | Prediction: -4.5887
# Target: -1.8770 | Prediction: -1.9414
# Target: -4.2600 | Prediction: -4.6427
# Target: -3.5200 | Prediction: -2.4519
# Target: -3.4800 | Prediction: -2.2620
# Target: -2.1800 | Prediction: -2.1273
# Target: -4.1100 | Prediction: -3.9268
# Target: -2.8900 | Prediction: -3.0812
# Target: -5.5400 | Prediction: -5.7130
# Target: -1.6010 | Prediction: -2.9532
# Target: -2.0800 | Prediction: -2.3227
# Target: -2.5600 | Prediction: -3.2455
# Target: -1.2280 | Prediction: -1.6652
# Target: -0.1000 | Prediction: -1.2822
# Target: -3.6500 | Prediction: -3.3011
# Target: -6.3500 | Prediction: -6.2463
# Target: -7.8000 | Prediction: -8.3059
# Target: -4.5710 | Prediction: -5.4511
# Target: -4.8900 | Prediction: -6.0062
# Target: -3.6800 | Prediction: -3.6981
# Target: -4.7100 | Prediction: -5.6659
# Target: -5.2930 | Prediction: -4.9627

# %%
# Calculate R^2
def calculate_r_squared(predictions, targets):
    ss_tot = np.sum((targets - np.mean(targets))**2)
    ss_res = np.sum((targets - predictions)**2)
    r_squared = 1 - (ss_res / ss_tot)
    return r_squared

# Convert lists to NumPy arrays
predictions = np.array(predictions)
targets = np.array(targets)

# Calculate Pearson correlation coefficient
corr, _ = pearsonr(predictions, targets)

print(f"Pearson Correlation Coefficient: {corr:.4f}")

r_squared = calculate_r_squared(predictions, targets)
print(f"Coefficient of Determination R^2: {r_squared:.4f}")

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(targets, predictions, color='blue', alpha=0.5)
plt.plot(targets, targets, color='red', linestyle='-', linewidth=2)  # Plot y=x line
plt.text(np.min(targets), np.max(predictions), f"Pearson Correlation: {corr:.4f}", fontsize=12, verticalalignment='top')
plt.title('Scatter Plot of Predictions vs Targets')
plt.xlabel('Targets')
plt.ylabel('Predictions')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson Correlation Coefficient: 0.9583
# Coefficient of Determination R^2: 0.9151

# %% [markdown]
# ## Know your molecules and true/prediction (Be warned if there is skipped molecule from test_samples! No skip -> correct structure!)

# %%
dataset = pd.read_csv(datadir+"esol.csv")

print(len(train_samples))
print(len(test_samples))
print(len(train_samples) + len(test_samples) )
print(len(dataset))
# Out:
# 902
# 226
# 1128
# 1128

# %%
# Load test_samples from CSV
dataset = pd.read_csv(datadir+"test.csv")
molecules = [molecule_from_smiles(dataset.smiles.values[i]) for i in range(len(test_samples))]

y_true = [targets[i] for i in range(len(test_samples))]
y_pred = [predictions[i] for i in range(len(test_samples))]

legends = [f"y_true/y_pred = {y_true[i]:.2f}/{y_pred[i]:.2f}" for i in range(len(test_samples))]
MolsToGridImage(molecules, molsPerRow=5, maxMols=100,legends=legends)
# Out:
# /Users/shampa/software/anaconda3/envs/py312/lib/python3.12/site-packages/rdkit/Chem/Draw/IPythonConsole.py:261: UserWarning: Truncating the list of molecules to be displayed to 100. Change the maxMols value to display more.
#   warnings.warn(

# %% [markdown]
# ## Future task: What is so unique about dihedral angles?
