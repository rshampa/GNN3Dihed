# %% [markdown]
# ## Know your libraries (KYL)

# %%
from dataset import QM9Dataset,LogSDataset,LogPDataset,FreeSolvDataset,ESOLDataset
import numpy as np
import pandas as pd
from utils import *
import torch
from scipy.stats import pearsonr
from tqdm import tqdm
from model import Autoencoder # Simply importing the autoencoder model module from the model.py file
from model import GNN3D

import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import MolsToGridImage

import os
import sys
datadir="../data/logs/"
modeldir="./models/logs/"
dataset_name="logs"
# Create datadir and modeldir folders if they don't exist
if not os.path.exists(datadir):
    os.makedirs(datadir)
    
if not os.path.exists(modeldir):
    os.makedirs(modeldir)
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Split your dataset (SYD)

# %%
# Load dataset from CSV
dataset = pd.read_csv(datadir+dataset_name+".csv")

# Split dataset into train and test
train_dataset, test_dataset = split_dataset(dataset, 0.8)

# Write train_dataset and test_dataset to CSV files
train_dataset.to_csv(datadir+"train.csv", index=False)
test_dataset.to_csv(datadir+"test.csv", index=False)

print("Train and test datasets saved successfully.")
# Out:
# Train and test datasets saved successfully.

# %% [markdown]
# ## Process your data (PYD)

# %%
train_samples = LogSDataset(datadir+"train")
print(train_samples)
print("===================================")
test_samples = LogSDataset(datadir+"test")
print(test_samples)
# Out:
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: LogS
# Number of Molecules Loaded: 1047
# ===================================
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: LogS
# Number of Molecules Loaded: 262

# %% [markdown]
# ## Know your featues (KYF)

# %%
# Printing out the dimensions of all of these features with a description of what each feature is
print(f"Atomic Features: {(train_samples[0])[0].shape} - This represents the atomic features of the molecule")
print(f"Bond Features: {(train_samples[0])[1].shape} - This represents the bond features of the molecule")
print(f"Angle Features: {(train_samples[0])[2].shape} - This represents the angle features of the molecule")
print(f"Dihedral Features: {(train_samples[0])[3].shape} - This represents the dihedral features of the molecule")
print(f"Global Molecular Features: {(train_samples[0])[4].shape} - This represents the global molecular features of the molecule")
print(f"Bond Indices: {(train_samples[0])[5].shape} - This represents the bond indices of the molecule")
print(f"Angle Indices: {(train_samples[0])[6].shape} - This represents the angle indices of the molecule")
print(f"Dihedral Indices: {(train_samples[0])[7].shape} - This represents the dihedral indices of the molecule")
print(f"Target: {(train_samples[0])[8].shape} - This represents the target of the molecule")
# Out:
# Atomic Features: torch.Size([29, 56]) - This represents the atomic features of the molecule
# Bond Features: torch.Size([60, 10]) - This represents the bond features of the molecule
# Angle Features: torch.Size([96]) - This represents the angle features of the molecule
# Dihedral Features: torch.Size([136]) - This represents the dihedral features of the molecule
# Global Molecular Features: torch.Size([200]) - This represents the global molecular features of the molecule
# Bond Indices: torch.Size([60, 2]) - This represents the bond indices of the molecule
# Angle Indices: torch.Size([96, 2]) - This represents the angle indices of the molecule
# Dihedral Indices: torch.Size([136, 2]) - This represents the dihedral indices of the molecule
# Target: torch.Size([1]) - This represents the target of the molecule

# %% [markdown]
# ## Know your modules (KYM)

# %%
def train_autoencoder_model(samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train Autoencoder: Atom and bond"""
    # Set the model in training mode
    atom_autoencoder.train()
    bond_autoencoder.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)

    # Lists to store losses
    avg_atom_rmse_losses = []
    avg_bond_rmse_losses = []

    for epoch_i in range(n_epochs):
        avg_atom_rmse_loss = 0
        avg_bond_rmse_loss = 0
        total_samples = 0
        
        for i, molecule in enumerate(samples):
            atom_features = molecule[0].to(device)
            bond_features = molecule[1].to(device)
            
            # Forward pass
            atom_features_reconstructed = atom_autoencoder(atom_features)
            bond_features_reconstructed = bond_autoencoder(bond_features)
            
            # Calculating loss
            atom_loss = mse_loss_fn(atom_features_reconstructed, atom_features)
            bond_loss = mse_loss_fn(bond_features_reconstructed, bond_features)
            
            # Backward pass and optimization step
            atom_optimizer.zero_grad()
            bond_optimizer.zero_grad()
            atom_loss.backward()
            bond_loss.backward()
            atom_optimizer.step()
            bond_optimizer.step()
            
            # Calculating average loss
            avg_atom_rmse_loss = (avg_atom_rmse_loss * total_samples + torch.sqrt(atom_loss).item()) / (total_samples + 1)
            avg_bond_rmse_loss = (avg_bond_rmse_loss * total_samples + torch.sqrt(bond_loss).item()) / (total_samples + 1)           
            total_samples += 1

            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3}/{n_epochs} | Samples: {i:>6}/{len(samples)} | Atom Avg. RMSE Loss: {avg_atom_rmse_loss:.4f} | Bond Avg. RMSE Loss: {avg_bond_rmse_loss:.4f}")
        
        # Append average losses for the epoch to lists
        avg_atom_rmse_losses.append(avg_atom_rmse_loss)
        avg_bond_rmse_losses.append(avg_bond_rmse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"autoencoder_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg Atom RMSE Loss\tAvg Bond RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i}\t{avg_atom_rmse_losses[epoch_i]}\t{avg_bond_rmse_losses[epoch_i]}\n")

    # Save model state
    torch.save(atom_autoencoder.state_dict(), f"{save_dir}atom_autoencoder_{dataset_name}.pth")
    torch.save(bond_autoencoder.state_dict(), f"{save_dir}bond_autoencoder_{dataset_name}.pth")
    
    return avg_atom_rmse_losses, avg_bond_rmse_losses
    



def process_molecule(molecule, atom_autoencoder, bond_autoencoder):
    """Separate input features and target"""
    # Ensure molecule has at least 8 elements
    if len(molecule) < 8:
        return None, None
    
    target = molecule[8].to(device)  # Assuming target is the 9th element (index 8)
    # Assuming first 8 elements are molecule graph input features:
    # atomic_features, bond_features, angle_features, dihedral_features, 
    # global_molecular_features, bond_indices, angle_indices,  dihedral_indices    
    molecule_data = [mol_elem.to(device) for mol_elem in molecule[:8]]
    
    # Putting latent atomic and bond features through encoders
    molecule_data[0] = atom_autoencoder.encode(molecule_data[0])
    molecule_data[1] = bond_autoencoder.encode(molecule_data[1])
    
    return molecule_data, target




def train_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train GNN3D"""
    # Set the model in training mode
    gnn3d.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)
   
    # Lists to store losses
    avg_rmse_losses = []
    avg_mse_losses = []

    for epoch_i in range(n_epochs):
        avg_rmse_loss = 0
        avg_mse_loss = 0
        total_samples = 0
        
        for i in tqdm(range(len(samples)), desc='Processing samples'):
            molecule_data, target = process_molecule(samples[i], atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)
            
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            
            # Backward pass
            gnn_optimizer.zero_grad()
            loss.backward()
            gnn_optimizer.step()
            
            # Calculating average loss
            avg_rmse_loss = (avg_rmse_loss * total_samples + torch.sqrt(loss).item()) / (total_samples + 1)
            avg_mse_loss = (avg_mse_loss * total_samples + loss.item()) / (total_samples + 1)
            total_samples += 1
            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3} | Samples: {i:>6}/{len(samples)} | Avg. RMSE Loss: {avg_rmse_loss:.4f} | Avg. MSE Loss: {avg_mse_loss:.4f}")

                # Append average losses for the epoch to lists
        avg_rmse_losses.append(avg_rmse_loss)
        avg_mse_losses.append(avg_mse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"gnn3d_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg RMSE Loss\tAvg RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i}\t{avg_rmse_losses[epoch_i]}\t{avg_mse_losses[epoch_i]}\n")

    # Save model state
    torch.save(gnn3d.state_dict(), f"{save_dir}gnn3d_{dataset_name}.pth")
    
    return avg_rmse_losses, avg_mse_losses




def evaluate_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder):
    """Evaluate GNN3D"""
    # Set the model in evaluation mode
    gnn3d.eval()

    # List to store predictions
    predictions = []
    targets = []
    
    avg_rmse_loss = 0
    avg_mse_loss = 0
    total_samples = 0
    
    with torch.no_grad():
        for i, molecule in enumerate(samples):
            molecule_data, target = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)

            # Extract target, prediction
            target_value = target.item()
            prediction_value = prediction.item()

            # For every test samples
            #print(f"Target: {target.item():.4f} | Prediction: {prediction.item():.4f}")
    
            # Store prediction
            predictions.append(prediction_value)
            targets.append(target_value)
                        
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            
            # Accumulate losses
            avg_rmse_loss += (torch.sqrt(loss).item())
            avg_mse_loss += loss.item()
            total_samples += 1
    
    # Calculate average losses
    avg_rmse_loss /= total_samples
    avg_mse_loss /= total_samples
    
    print(f"Evaluation Results:")
    print(f"Avg. RMSE Loss: {avg_rmse_loss:.4f}")
    print(f"Avg. MSE Loss: {avg_mse_loss:.4f}")
    
    return predictions, targets

# %% [markdown]
# ## Training

# %% [markdown]
# ### Autoencoder training

# %%
atom_autoencoder = Autoencoder(56, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
atom_optimizer = torch.optim.Adam(atom_autoencoder.parameters())
bond_optimizer = torch.optim.Adam(bond_autoencoder.parameters())

atom_losses, bond_losses = train_autoencoder_model(train_samples, atom_autoencoder, bond_autoencoder, n_epochs=20, printstep=500, save_dir=modeldir, dataset_name=dataset_name)
# Out:
# Epoch:   0/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.3633 | Bond Avg. RMSE Loss: 0.4746
# Epoch:   0/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.1655 | Bond Avg. RMSE Loss: 0.3048
# Epoch:   0/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.1224 | Bond Avg. RMSE Loss: 0.2249
# Epoch:   1/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0563 | Bond Avg. RMSE Loss: 0.0828
# Epoch:   1/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0605 | Bond Avg. RMSE Loss: 0.1146
# Epoch:   1/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0560 | Bond Avg. RMSE Loss: 0.1039
# Epoch:   2/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0418 | Bond Avg. RMSE Loss: 0.0758
# Epoch:   2/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0495 | Bond Avg. RMSE Loss: 0.0710
# Epoch:   2/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0481 | Bond Avg. RMSE Loss: 0.0651
# Epoch:   3/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0412 | Bond Avg. RMSE Loss: 0.0426
# Epoch:   3/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0458 | Bond Avg. RMSE Loss: 0.0368
# Epoch:   3/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0452 | Bond Avg. RMSE Loss: 0.0343
# Epoch:   4/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0405 | Bond Avg. RMSE Loss: 0.0141
# Epoch:   4/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0446 | Bond Avg. RMSE Loss: 0.0266
# Epoch:   4/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0437 | Bond Avg. RMSE Loss: 0.0280
# Epoch:   5/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0404 | Bond Avg. RMSE Loss: 0.0134
# Epoch:   5/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0431 | Bond Avg. RMSE Loss: 0.0250
# Epoch:   5/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0424 | Bond Avg. RMSE Loss: 0.0262
# Epoch:   6/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0405 | Bond Avg. RMSE Loss: 0.0127
# Epoch:   6/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0421 | Bond Avg. RMSE Loss: 0.0238
# Epoch:   6/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0412 | Bond Avg. RMSE Loss: 0.0249
# Epoch:   7/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0404 | Bond Avg. RMSE Loss: 0.0102
# Epoch:   7/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0416 | Bond Avg. RMSE Loss: 0.0221
# Epoch:   7/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0407 | Bond Avg. RMSE Loss: 0.0230
# Epoch:   8/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0426 | Bond Avg. RMSE Loss: 0.0078
# Epoch:   8/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0417 | Bond Avg. RMSE Loss: 0.0200
# Epoch:   8/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0407 | Bond Avg. RMSE Loss: 0.0204
# Epoch:   9/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0400 | Bond Avg. RMSE Loss: 0.0053
# Epoch:   9/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0403 | Bond Avg. RMSE Loss: 0.0173
# Epoch:   9/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0400 | Bond Avg. RMSE Loss: 0.0176
# Epoch:  10/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0404 | Bond Avg. RMSE Loss: 0.0035
# Epoch:  10/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0409 | Bond Avg. RMSE Loss: 0.0152
# Epoch:  10/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0400 | Bond Avg. RMSE Loss: 0.0155
# Epoch:  11/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0399 | Bond Avg. RMSE Loss: 0.0032
# Epoch:  11/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0416 | Bond Avg. RMSE Loss: 0.0130
# Epoch:  11/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0403 | Bond Avg. RMSE Loss: 0.0137
# Epoch:  12/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0396 | Bond Avg. RMSE Loss: 0.0027
# Epoch:  12/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0398 | Bond Avg. RMSE Loss: 0.0119
# Epoch:  12/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0394 | Bond Avg. RMSE Loss: 0.0125
# Epoch:  13/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0394 | Bond Avg. RMSE Loss: 0.0033
# Epoch:  13/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0408 | Bond Avg. RMSE Loss: 0.0109
# Epoch:  13/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0397 | Bond Avg. RMSE Loss: 0.0114
# Epoch:  14/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0394 | Bond Avg. RMSE Loss: 0.0027
# Epoch:  14/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0397 | Bond Avg. RMSE Loss: 0.0096
# Epoch:  14/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0394 | Bond Avg. RMSE Loss: 0.0104
# Epoch:  15/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0395 | Bond Avg. RMSE Loss: 0.0035
# Epoch:  15/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0406 | Bond Avg. RMSE Loss: 0.0090
# Epoch:  15/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0396 | Bond Avg. RMSE Loss: 0.0093
# Epoch:  16/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0395 | Bond Avg. RMSE Loss: 0.0027
# Epoch:  16/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0399 | Bond Avg. RMSE Loss: 0.0066
# Epoch:  16/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0393 | Bond Avg. RMSE Loss: 0.0092
# Epoch:  17/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0397 | Bond Avg. RMSE Loss: 0.0033
# Epoch:  17/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0394 | Bond Avg. RMSE Loss: 0.0073
# Epoch:  17/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0391 | Bond Avg. RMSE Loss: 0.0087
# Epoch:  18/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0398 | Bond Avg. RMSE Loss: 0.0035
# Epoch:  18/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0415 | Bond Avg. RMSE Loss: 0.0069
# Epoch:  18/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0400 | Bond Avg. RMSE Loss: 0.0083
# Epoch:  19/20 | Samples:      0/1047 | Atom Avg. RMSE Loss: 0.0396 | Bond Avg. RMSE Loss: 0.0035
# Epoch:  19/20 | Samples:    500/1047 | Atom Avg. RMSE Loss: 0.0389 | Bond Avg. RMSE Loss: 0.0063
# Epoch:  19/20 | Samples:   1000/1047 | Atom Avg. RMSE Loss: 0.0388 | Bond Avg. RMSE Loss: 0.0085

# %%
# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
#plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Atom Autoencoder Training Losses for {dataset_name}")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}atom_autoencoder_losses_{dataset_name}.png")
plt.show()

# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
#plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Bond Autoencoder Training Losses for {dataset_name}")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}bond_autoencoder_losses_{dataset_name}.png")
plt.show()

# %% [markdown]
# ### GNN3D training

# %%
atom_autoencoder = Autoencoder(56, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
gnn3d = GNN3D(atomic_vector_size=10, bond_vector_size=3, number_of_molecular_features=200, number_of_targets=1).to(device)
gnn_optimizer = torch.optim.Adam(gnn3d.parameters())
rmse_losses, mse_losses = train_gnn3d_model(gnn3d, train_samples, atom_autoencoder, bond_autoencoder, n_epochs=20, printstep=500, save_dir=modeldir, dataset_name=dataset_name)
# Out:
# Processing samples:   0%|▍                                                                                                                                     | 3/1047 [00:00<01:32, 11.24it/s]
# Epoch:   0 | Samples:      0/1047 | Avg. RMSE Loss: 2.6215 | Avg. MSE Loss: 6.8722
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:38, 14.05it/s]
# Epoch:   0 | Samples:    500/1047 | Avg. RMSE Loss: 1.1595 | Avg. MSE Loss: 2.5451
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.46it/s]
# Epoch:   0 | Samples:   1000/1047 | Avg. RMSE Loss: 0.9588 | Avg. MSE Loss: 1.7380
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.71it/s]
# Processing samples:   0%|▍                                                                                                                                     | 3/1047 [00:00<01:18, 13.24it/s]
# Epoch:   1 | Samples:      0/1047 | Avg. RMSE Loss: 0.8351 | Avg. MSE Loss: 0.6974
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.68it/s]
# Epoch:   1 | Samples:    500/1047 | Avg. RMSE Loss: 0.6352 | Avg. MSE Loss: 0.6587
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.87it/s]
# Epoch:   1 | Samples:   1000/1047 | Avg. RMSE Loss: 0.6102 | Avg. MSE Loss: 0.6195
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.74it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:09, 15.04it/s]
# Epoch:   2 | Samples:      0/1047 | Avg. RMSE Loss: 0.6935 | Avg. MSE Loss: 0.4810
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:39<00:39, 13.84it/s]
# Epoch:   2 | Samples:    500/1047 | Avg. RMSE Loss: 0.5588 | Avg. MSE Loss: 0.5230
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.71it/s]
# Epoch:   2 | Samples:   1000/1047 | Avg. RMSE Loss: 0.5458 | Avg. MSE Loss: 0.5039
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.77it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:09, 15.01it/s]
# Epoch:   3 | Samples:      0/1047 | Avg. RMSE Loss: 0.6526 | Avg. MSE Loss: 0.4259
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.80it/s]
# Epoch:   3 | Samples:    500/1047 | Avg. RMSE Loss: 0.5238 | Avg. MSE Loss: 0.4640
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.86it/s]
# Epoch:   3 | Samples:   1000/1047 | Avg. RMSE Loss: 0.5134 | Avg. MSE Loss: 0.4460
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.75it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.72it/s]
# Epoch:   4 | Samples:      0/1047 | Avg. RMSE Loss: 0.5701 | Avg. MSE Loss: 0.3250
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:38, 14.01it/s]
# Epoch:   4 | Samples:    500/1047 | Avg. RMSE Loss: 0.4959 | Avg. MSE Loss: 0.4241
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.89it/s]
# Epoch:   4 | Samples:   1000/1047 | Avg. RMSE Loss: 0.4887 | Avg. MSE Loss: 0.4088
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.70it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.87it/s]
# Epoch:   5 | Samples:      0/1047 | Avg. RMSE Loss: 0.6022 | Avg. MSE Loss: 0.3626
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:38, 13.98it/s]
# Epoch:   5 | Samples:    500/1047 | Avg. RMSE Loss: 0.4760 | Avg. MSE Loss: 0.3898
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.90it/s]
# Epoch:   5 | Samples:   1000/1047 | Avg. RMSE Loss: 0.4692 | Avg. MSE Loss: 0.3772
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.74it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.82it/s]
# Epoch:   6 | Samples:      0/1047 | Avg. RMSE Loss: 0.5744 | Avg. MSE Loss: 0.3299
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:38, 13.98it/s]
# Epoch:   6 | Samples:    500/1047 | Avg. RMSE Loss: 0.4592 | Avg. MSE Loss: 0.3621
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.95it/s]
# Epoch:   6 | Samples:   1000/1047 | Avg. RMSE Loss: 0.4515 | Avg. MSE Loss: 0.3493
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.73it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:09, 15.02it/s]
# Epoch:   7 | Samples:      0/1047 | Avg. RMSE Loss: 0.5802 | Avg. MSE Loss: 0.3366
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:39<00:38, 14.03it/s]
# Epoch:   7 | Samples:    500/1047 | Avg. RMSE Loss: 0.4457 | Avg. MSE Loss: 0.3429
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.82it/s]
# Epoch:   7 | Samples:   1000/1047 | Avg. RMSE Loss: 0.4399 | Avg. MSE Loss: 0.3321
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.75it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.73it/s]
# Epoch:   8 | Samples:      0/1047 | Avg. RMSE Loss: 0.5807 | Avg. MSE Loss: 0.3372
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:39<00:39, 13.90it/s]
# Epoch:   8 | Samples:    500/1047 | Avg. RMSE Loss: 0.4297 | Avg. MSE Loss: 0.3200
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.92it/s]
# Epoch:   8 | Samples:   1000/1047 | Avg. RMSE Loss: 0.4253 | Avg. MSE Loss: 0.3130
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.75it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:09, 15.09it/s]
# Epoch:   9 | Samples:      0/1047 | Avg. RMSE Loss: 0.5528 | Avg. MSE Loss: 0.3056
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.93it/s]
# Epoch:   9 | Samples:    500/1047 | Avg. RMSE Loss: 0.4180 | Avg. MSE Loss: 0.3035
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:19<00:03, 12.83it/s]
# Epoch:   9 | Samples:   1000/1047 | Avg. RMSE Loss: 0.4129 | Avg. MSE Loss: 0.2954
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.70it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.87it/s]
# Epoch:  10 | Samples:      0/1047 | Avg. RMSE Loss: 0.5277 | Avg. MSE Loss: 0.2785
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.95it/s]
# Epoch:  10 | Samples:    500/1047 | Avg. RMSE Loss: 0.4083 | Avg. MSE Loss: 0.2903
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.80it/s]
# Epoch:  10 | Samples:   1000/1047 | Avg. RMSE Loss: 0.4031 | Avg. MSE Loss: 0.2821
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.71it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:09, 15.06it/s]
# Epoch:  11 | Samples:      0/1047 | Avg. RMSE Loss: 0.5061 | Avg. MSE Loss: 0.2561
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:38, 14.00it/s]
# Epoch:  11 | Samples:    500/1047 | Avg. RMSE Loss: 0.3959 | Avg. MSE Loss: 0.2746
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.83it/s]
# Epoch:  11 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3934 | Avg. MSE Loss: 0.2704
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.72it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:09, 15.07it/s]
# Epoch:  12 | Samples:      0/1047 | Avg. RMSE Loss: 0.4159 | Avg. MSE Loss: 0.1730
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:39<00:38, 14.07it/s]
# Epoch:  12 | Samples:    500/1047 | Avg. RMSE Loss: 0.3885 | Avg. MSE Loss: 0.2612
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.79it/s]
# Epoch:  12 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3845 | Avg. MSE Loss: 0.2569
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.71it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.73it/s]
# Epoch:  13 | Samples:      0/1047 | Avg. RMSE Loss: 0.4208 | Avg. MSE Loss: 0.1771
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.82it/s]
# Epoch:  13 | Samples:    500/1047 | Avg. RMSE Loss: 0.3764 | Avg. MSE Loss: 0.2484
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.88it/s]
# Epoch:  13 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3767 | Avg. MSE Loss: 0.2473
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.73it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:09, 14.93it/s]
# Epoch:  14 | Samples:      0/1047 | Avg. RMSE Loss: 0.3540 | Avg. MSE Loss: 0.1253
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.74it/s]
# Epoch:  14 | Samples:    500/1047 | Avg. RMSE Loss: 0.3712 | Avg. MSE Loss: 0.2396
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.75it/s]
# Epoch:  14 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3713 | Avg. MSE Loss: 0.2392
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.72it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.86it/s]
# Epoch:  15 | Samples:      0/1047 | Avg. RMSE Loss: 0.3855 | Avg. MSE Loss: 0.1486
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:39<00:39, 13.97it/s]
# Epoch:  15 | Samples:    500/1047 | Avg. RMSE Loss: 0.3644 | Avg. MSE Loss: 0.2323
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:18<00:03, 12.76it/s]
# Epoch:  15 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3643 | Avg. MSE Loss: 0.2310
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.74it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.87it/s]
# Epoch:  16 | Samples:      0/1047 | Avg. RMSE Loss: 0.3269 | Avg. MSE Loss: 0.1069
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.70it/s]
# Epoch:  16 | Samples:    500/1047 | Avg. RMSE Loss: 0.3550 | Avg. MSE Loss: 0.2223
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:20<00:03, 12.72it/s]
# Epoch:  16 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3567 | Avg. MSE Loss: 0.2217
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:23<00:00, 12.54it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:08, 15.15it/s]
# Epoch:  17 | Samples:      0/1047 | Avg. RMSE Loss: 0.3077 | Avg. MSE Loss: 0.0947
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.83it/s]
# Epoch:  17 | Samples:    500/1047 | Avg. RMSE Loss: 0.3507 | Avg. MSE Loss: 0.2151
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:19<00:03, 12.77it/s]
# Epoch:  17 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3514 | Avg. MSE Loss: 0.2161
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.65it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:10, 14.88it/s]
# Epoch:  18 | Samples:      0/1047 | Avg. RMSE Loss: 0.2638 | Avg. MSE Loss: 0.0696
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.73it/s]
# Epoch:  18 | Samples:    500/1047 | Avg. RMSE Loss: 0.3475 | Avg. MSE Loss: 0.2116
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:19<00:03, 12.81it/s]
# Epoch:  18 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3472 | Avg. MSE Loss: 0.2108
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.66it/s]
# Processing samples:   0%|▌                                                                                                                                     | 4/1047 [00:00<01:08, 15.19it/s]
# Epoch:  19 | Samples:      0/1047 | Avg. RMSE Loss: 0.2961 | Avg. MSE Loss: 0.0877
# Processing samples:  48%|███████████████████████████████████████████████████████████████▎                                                                    | 502/1047 [00:40<00:39, 13.96it/s]
# Epoch:  19 | Samples:    500/1047 | Avg. RMSE Loss: 0.3420 | Avg. MSE Loss: 0.2041
# Processing samples:  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎     | 1002/1047 [01:19<00:03, 12.62it/s]
# Epoch:  19 | Samples:   1000/1047 | Avg. RMSE Loss: 0.3451 | Avg. MSE Loss: 0.2064
# Processing samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1047/1047 [01:22<00:00, 12.65it/s]

# %%
# Assuming rmse_losses is the list of RMSE losses obtained from training
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(rmse_losses)+1), rmse_losses, marker='o', linestyle='-', color='b', label='Avg. RMSE Loss')
plt.title(f"GNN3D Training Losses for {dataset_name}")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}gnn3d_rmse_losses_{dataset_name}.png")
plt.show()

# %% [markdown]
# ## Testing

# %%
predictions, targets = evaluate_gnn3d_model( gnn3d, test_samples, atom_autoencoder, bond_autoencoder)
# Out:
# Evaluation Results:
# Avg. RMSE Loss: 0.4648
# Avg. MSE Loss: 0.3950

# %% [markdown]
# ## Know your correlations (KYC)

# %%
# Calculate R^2
def calculate_r_squared(predictions, targets):
    ss_tot = np.sum((targets - np.mean(targets))**2)
    ss_res = np.sum((targets - predictions)**2)
    r_squared = 1 - (ss_res / ss_tot)
    return r_squared

# Convert lists to NumPy arrays
predictions = np.array(predictions)
targets = np.array(targets)

# Calculate Pearson correlation coefficient
corr, _ = pearsonr(predictions, targets)

print(f"Pearson Correlation Coefficient: {corr:.4f}")

r_squared = calculate_r_squared(predictions, targets)
print(f"Coefficient of Determination R^2: {r_squared:.4f}")

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(targets, predictions, color='blue', alpha=0.5)
plt.plot(targets, targets, color='red', linestyle='-', linewidth=2)  # Plot y=x line
plt.text(np.min(targets), np.max(predictions), f"Pearson Correlation: {corr:.4f}", fontsize=12, verticalalignment='top')
plt.title('Scatter Plot of Predictions vs Targets')
plt.xlabel('Targets')
plt.ylabel('Predictions')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson Correlation Coefficient: 0.9491
# Coefficient of Determination R^2: 0.9007

# %% [markdown]
# ## Know your molecules and true/prediction (Be warned if there is skipped molecule from test_samples! No skip -> correct structure!)

# %%
print(f"Loaded train samples: {len(train_samples)}")
print(f"Loaded test samples: {len(test_samples)}")
print(f"Total (train+test): {len(train_samples) + len(test_samples)}" )
print(f"Total from dataset: {len(dataset)}")
print(f"80% of dataset: {int(0.8*len(dataset))}")
print(f"20% of dataset: {int(0.2*len(dataset))}")
print(f"NOT Skipped molecule, therefore following output of next cell is correct!")
# Out:
# Loaded train samples: 1047
# Loaded test samples: 262
# Total (train+test): 1309
# Total from dataset: 1310
# 80% of dataset: 1048
# 20% of dataset: 262
# NOT Skipped molecule, therefore following output of next cell is correct!

# %%
# Load test_samples from CSV
test_dataset = pd.read_csv(datadir+"test.csv")
#molecules = [molecule_from_smiles(test_dataset.smiles.values[i]) for i in range(len(test_samples))]
molecules = test_dataset['smiles'].apply(lambda x: Chem.MolFromSmiles(x)) 

y_true = [targets[i] for i in range(len(test_samples))]
y_pred = [predictions[i] for i in range(len(test_samples))]

legends = [f"y_true/y_pred = {y_true[i]:.2f}/{y_pred[i]:.2f}" for i in range(len(test_samples))]
MolsToGridImage(molecules, molsPerRow=5, maxMols=100,legends=legends)
# Out:
# /Users/shampa/software/anaconda3/envs/py312/lib/python3.12/site-packages/rdkit/Chem/Draw/IPythonConsole.py:261: UserWarning: Truncating the list of molecules to be displayed to 100. Change the maxMols value to display more.
#   warnings.warn(

# %%
df = pd.read_csv(datadir+"test.csv")      #Reading logS: y_true dataframe
df['preds'] = predictions
df
# Out:
#                                                 smiles  logS     preds
# 0                                               CCOC=O  0.15  0.018478
# 1                                           OC(CCl)CCl -0.11  0.283350
# 2                      CC12CCC3C(CCC4CCCCC34C)C1CCC2=O -6.70 -5.019769
# 3    COC1=CC2=C(C=C1)N(C(=O)C1=CC=C(Cl)C=C1)C(C)=C2... -4.62 -5.241838
# 4                             CC(OC1=CC=CC=C1Cl)C(O)=O -2.22 -2.066575
# ..                                                 ...   ...       ...
# 257                             O=C1OC(=O)C2=CC=CC=C12 -1.39 -1.313951
# 258                       OC(=O)CC1=C(Cl)C=CC(Cl)=C1Cl -3.08 -2.879692
# 259                                       CCCCC(C)(C)O -1.08 -1.192462
# 260                         O=N(=O)C1=CC=CC2=C1C=CC=C2 -3.54 -3.738989
# 261                                          ClCCOCCCl -1.12 -1.493534
#
# [262 rows x 3 columns]

# %% [markdown]
# ## Future task: What is so unique about dihedral angles?

# %%
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
from sklearn.metrics import mean_absolute_error, root_mean_squared_error

def plot_parity(y_true, y_pred, y_pred_unc=None):
    
    axmin = min(min(y_true), min(y_pred)) - 0.1*(max(y_true)-min(y_true))
    axmax = max(max(y_true), max(y_pred)) + 0.1*(max(y_true)-min(y_true))
    
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    
    plt.plot([axmin, axmax], [axmin, axmax], '--k')

    plt.errorbar(y_true, y_pred, yerr=y_pred_unc, linewidth=0, marker='o', markeredgecolor='w', alpha=1, elinewidth=1)
    
    plt.xlim((axmin, axmax))
    plt.ylim((axmin, axmax))
    
    ax = plt.gca()
    ax.set_aspect('equal')
    
    at = AnchoredText(
    f"MAE = {mae:.2f}\nRMSE = {rmse:.2f}", prop=dict(size=10), frameon=True, loc='upper left')
    at.patch.set_boxstyle("round,pad=0.,rounding_size=0.2")
    ax.add_artist(at)
    
    plt.xlabel('True')
    plt.ylabel('GNN3Dihed Predicted')
    
    plt.show()
    
    return

# %%
plot_parity(df.logS, df.preds)
