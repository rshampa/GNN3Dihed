# %% [markdown]
# ## Know your libraries (KYL)

# %%
from dataset import QM9,LogSDataset,LogPDataset
import numpy as np
import pandas as pd
from utils import *
import torch
from model import Autoencoder # Simply importing the autoencoder model module from the model.py file
from model import GNN3D

import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import MolsToGridImage

import os

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Split your dataset (SYD)

# %%
# Load dataset from CSV
dataset = pd.read_csv("../data/logs_50.csv")

# Split dataset into train and test
train_dataset, test_dataset = split_dataset(dataset, 0.9)

# Write train_dataset and test_dataset to CSV files
train_dataset.to_csv("../data/train.csv", index=False)
test_dataset.to_csv("../data/test.csv", index=False)

print("Train and test datasets saved successfully.")
# Out:
# Train and test datasets saved successfully.

# %% [markdown]
# ## Process your data (PYD)

# %%
train_samples = LogSDataset("../data/train")
print(train_samples)
print("===================================")
test_samples = LogSDataset("../data/test")
print(test_samples)
# Out:
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: LogS
# Number of Molecules Loaded: 45
# ===================================
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: LogS
# Number of Molecules Loaded: 5

# %% [markdown]
# ## Know your featues (KYF)

# %%
# Printing out the dimensions of all of these features with a description of what each feature is
print(f"Atomic Features: {(train_samples[0])[0].shape} - This represents the atomic features of the molecule")
print(f"Bond Features: {(train_samples[0])[1].shape} - This represents the bond features of the molecule")
print(f"Angle Features: {(train_samples[0])[2].shape} - This represents the angle features of the molecule")
print(f"Dihedral Features: {(train_samples[0])[3].shape} - This represents the dihedral features of the molecule")
print(f"Global Molecular Features: {(train_samples[0])[4].shape} - This represents the global molecular features of the molecule")
print(f"Bond Indices: {(train_samples[0])[5].shape} - This represents the bond indices of the molecule")
print(f"Angle Indices: {(train_samples[0])[6].shape} - This represents the angle indices of the molecule")
print(f"Dihedral Indices: {(train_samples[0])[7].shape} - This represents the dihedral indices of the molecule")
print(f"Target: {(train_samples[0])[8].shape} - This represents the target of the molecule")
# Out:
# Atomic Features: torch.Size([9, 154]) - This represents the atomic features of the molecule
# Bond Features: torch.Size([16, 10]) - This represents the bond features of the molecule
# Angle Features: torch.Size([24]) - This represents the angle features of the molecule
# Dihedral Features: torch.Size([20]) - This represents the dihedral features of the molecule
# Global Molecular Features: torch.Size([200]) - This represents the global molecular features of the molecule
# Bond Indices: torch.Size([16, 2]) - This represents the bond indices of the molecule
# Angle Indices: torch.Size([24, 2]) - This represents the angle indices of the molecule
# Dihedral Indices: torch.Size([20, 2]) - This represents the dihedral indices of the molecule
# Target: torch.Size([1]) - This represents the target of the molecule

# %% [markdown]
# ## Know your modules (KYM)

# %%
def train_autoencoder_model(samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train Autoencoder: Atom and bond"""
    # Set the model in training mode
    atom_autoencoder.train()
    bond_autoencoder.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)

    # Lists to store losses
    avg_atom_rmse_losses = []
    avg_bond_rmse_losses = []

    for epoch_i in range(n_epochs):
        avg_atom_rmse_loss = 0
        avg_bond_rmse_loss = 0
        total_samples = 0
        
        for i, molecule in enumerate(samples):
            atom_features = molecule[0].to(device)
            bond_features = molecule[1].to(device)
            
            # Forward pass
            atom_features_reconstructed = atom_autoencoder(atom_features)
            bond_features_reconstructed = bond_autoencoder(bond_features)
            
            # Calculating loss
            atom_loss = mse_loss_fn(atom_features_reconstructed, atom_features)
            bond_loss = mse_loss_fn(bond_features_reconstructed, bond_features)
            
            # Backward pass and optimization step
            atom_optimizer.zero_grad()
            bond_optimizer.zero_grad()
            atom_loss.backward()
            bond_loss.backward()
            atom_optimizer.step()
            bond_optimizer.step()
            
            # Calculating average loss
            avg_atom_rmse_loss = (avg_atom_rmse_loss * total_samples + (atom_loss.item() ** 0.5)) / (total_samples + 1)
            avg_bond_rmse_loss = (avg_bond_rmse_loss * total_samples + (bond_loss.item() ** 0.5)) / (total_samples + 1)           
            total_samples += 1

            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i + 1:>3}/{n_epochs} | Sample: {i + 1:>6}/{len(samples)} | Atom Avg. RMSE Loss: {avg_atom_rmse_loss:.4f} | Bond Avg. RMSE Loss: {avg_bond_rmse_loss:.4f}")
        
        # Append average losses for the epoch to lists
        avg_atom_rmse_losses.append(avg_atom_rmse_loss)
        avg_bond_rmse_losses.append(avg_bond_rmse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"autoencoder_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg Atom RMSE Loss\tAvg Bond RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i+1}\t{avg_atom_rmse_losses[epoch_i]}\t{avg_bond_rmse_losses[epoch_i]}\n")
    
    return avg_atom_rmse_losses, avg_bond_rmse_losses
    



def process_molecule(molecule, atom_autoencoder, bond_autoencoder):
    """Separate input features and target"""
    # Ensure molecule has at least 8 elements
    if len(molecule) < 8:
        return None, None
    
    target = molecule[8].to(device)  # Assuming target is the 9th element (index 8)
    # Assuming first 8 elements are molecule graph input features:
    # atomic_features, bond_features, angle_features, dihedral_features, 
    # global_molecular_features, bond_indices, angle_indices,  dihedral_indices    
    molecule_data = [mol_elem.to(device) for mol_elem in molecule[:8]]
    
    # Putting latent atomic and bond features through encoders
    molecule_data[0] = atom_autoencoder.encode(molecule_data[0])
    molecule_data[1] = bond_autoencoder.encode(molecule_data[1])
    
    return molecule_data, target




def train_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train GNN3D"""
    # Set the model in training mode
    gnn3d.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)

    # Lists to store losses
    avg_rmse_losses = []
    avg_mse_losses = []

    for epoch_i in range(n_epochs):
        avg_rmse_loss = 0
        avg_mse_loss = 0
        total_samples = 0
        
        for i, molecule in enumerate(samples):
            molecule_data, target = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)
            
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            
            # Backward pass
            gnn_optimizer.zero_grad()
            loss.backward()
            gnn_optimizer.step()
            
            # Calculating average loss
            avg_rmse_loss = (avg_rmse_loss * total_samples + (loss.item() ** 0.5)) / (total_samples + 1)
            avg_mse_loss = (avg_mse_loss * total_samples + loss.item()) / (total_samples + 1)
            total_samples += 1
            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3} | Samples: {i:>6} | Avg. RMSE Loss: {avg_rmse_loss:.4f} | Avg. MSE Loss: {avg_mse_loss:.4f}")

                # Append average losses for the epoch to lists
        avg_rmse_losses.append(avg_rmse_loss)
        avg_mse_losses.append(avg_mse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"gnn3d_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg RMSE Loss\tAvg RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i+1}\t{avg_rmse_losses[epoch_i]}\t{avg_mse_losses[epoch_i]}\n")

    return avg_rmse_losses, avg_mse_losses




def evaluate_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder):
    """Evaluate GNN3D"""
    # Set the model in evaluation mode
    gnn3d.eval()

    avg_rmse_loss = 0
    avg_mse_loss = 0
    total_samples = 0
    
    with torch.no_grad():
        for i, molecule in enumerate(samples):
            molecule_data, target = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)
            
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            
            # Accumulate losses
            avg_rmse_loss += (loss.item() ** 0.5)
            avg_mse_loss += loss.item()
            total_samples += 1
    
    # Calculate average losses
    avg_rmse_loss /= total_samples
    avg_mse_loss /= total_samples
    
    print(f"Evaluation Results:")
    print(f"Avg. RMSE Loss: {avg_rmse_loss:.4f}")
    print(f"Avg. MSE Loss: {avg_mse_loss:.4f}")
    
    return avg_rmse_loss, avg_mse_loss

# %% [markdown]
# ## Training

# %% [markdown]
# ### Autoencoder training

# %%
# Autoencoder Training
atom_autoencoder = Autoencoder(154, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
 
mse_loss_fn = torch.nn.MSELoss()

atom_optimizer = torch.optim.Adam(atom_autoencoder.parameters())
bond_optimizer = torch.optim.Adam(bond_autoencoder.parameters())

atom_losses, bond_losses = train_autoencoder_model(train_samples, atom_autoencoder, bond_autoencoder, n_epochs=12, printstep=10, save_dir="./models/", dataset_name="logs")
# Out:
# Epoch:   1/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.2023 | Bond Avg. RMSE Loss: 0.4990
# Epoch:   1/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.2014 | Bond Avg. RMSE Loss: 0.5142
# Epoch:   1/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.1957 | Bond Avg. RMSE Loss: 0.5152
# Epoch:   1/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.1841 | Bond Avg. RMSE Loss: 0.5088
# Epoch:   1/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.1709 | Bond Avg. RMSE Loss: 0.5064
# Epoch:   2/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.1131 | Bond Avg. RMSE Loss: 0.4792
# Epoch:   2/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.1241 | Bond Avg. RMSE Loss: 0.4934
# Epoch:   2/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.1242 | Bond Avg. RMSE Loss: 0.4932
# Epoch:   2/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.1225 | Bond Avg. RMSE Loss: 0.4851
# Epoch:   2/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.1221 | Bond Avg. RMSE Loss: 0.4811
# Epoch:   3/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.1097 | Bond Avg. RMSE Loss: 0.4448
# Epoch:   3/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.1193 | Bond Avg. RMSE Loss: 0.4554
# Epoch:   3/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.1174 | Bond Avg. RMSE Loss: 0.4507
# Epoch:   3/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.1117 | Bond Avg. RMSE Loss: 0.4366
# Epoch:   3/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.1067 | Bond Avg. RMSE Loss: 0.4270
# Epoch:   4/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0805 | Bond Avg. RMSE Loss: 0.3598
# Epoch:   4/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0871 | Bond Avg. RMSE Loss: 0.3651
# Epoch:   4/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0852 | Bond Avg. RMSE Loss: 0.3527
# Epoch:   4/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0836 | Bond Avg. RMSE Loss: 0.3288
# Epoch:   4/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0829 | Bond Avg. RMSE Loss: 0.3171
# Epoch:   5/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0770 | Bond Avg. RMSE Loss: 0.2533
# Epoch:   5/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0823 | Bond Avg. RMSE Loss: 0.2735
# Epoch:   5/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0806 | Bond Avg. RMSE Loss: 0.2731
# Epoch:   5/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0794 | Bond Avg. RMSE Loss: 0.2568
# Epoch:   5/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0786 | Bond Avg. RMSE Loss: 0.2546
# Epoch:   6/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0713 | Bond Avg. RMSE Loss: 0.2237
# Epoch:   6/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0769 | Bond Avg. RMSE Loss: 0.2543
# Epoch:   6/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0754 | Bond Avg. RMSE Loss: 0.2593
# Epoch:   6/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0735 | Bond Avg. RMSE Loss: 0.2464
# Epoch:   6/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0722 | Bond Avg. RMSE Loss: 0.2458
# Epoch:   7/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0595 | Bond Avg. RMSE Loss: 0.2177
# Epoch:   7/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0678 | Bond Avg. RMSE Loss: 0.2515
# Epoch:   7/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0658 | Bond Avg. RMSE Loss: 0.2572
# Epoch:   7/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0639 | Bond Avg. RMSE Loss: 0.2445
# Epoch:   7/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0620 | Bond Avg. RMSE Loss: 0.2440
# Epoch:   8/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0530 | Bond Avg. RMSE Loss: 0.2143
# Epoch:   8/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0602 | Bond Avg. RMSE Loss: 0.2488
# Epoch:   8/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0590 | Bond Avg. RMSE Loss: 0.2544
# Epoch:   8/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0584 | Bond Avg. RMSE Loss: 0.2412
# Epoch:   8/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0566 | Bond Avg. RMSE Loss: 0.2404
# Epoch:   9/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0531 | Bond Avg. RMSE Loss: 0.2075
# Epoch:   9/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0566 | Bond Avg. RMSE Loss: 0.2438
# Epoch:   9/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0558 | Bond Avg. RMSE Loss: 0.2497
# Epoch:   9/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0559 | Bond Avg. RMSE Loss: 0.2362
# Epoch:   9/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0543 | Bond Avg. RMSE Loss: 0.2356
# Epoch:  10/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0522 | Bond Avg. RMSE Loss: 0.2025
# Epoch:  10/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0548 | Bond Avg. RMSE Loss: 0.2402
# Epoch:  10/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0542 | Bond Avg. RMSE Loss: 0.2466
# Epoch:  10/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0546 | Bond Avg. RMSE Loss: 0.2331
# Epoch:  10/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0530 | Bond Avg. RMSE Loss: 0.2325
# Epoch:  11/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0513 | Bond Avg. RMSE Loss: 0.1998
# Epoch:  11/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0536 | Bond Avg. RMSE Loss: 0.2373
# Epoch:  11/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0529 | Bond Avg. RMSE Loss: 0.2438
# Epoch:  11/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0533 | Bond Avg. RMSE Loss: 0.2303
# Epoch:  11/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0517 | Bond Avg. RMSE Loss: 0.2296
# Epoch:  12/12 | Sample:      1/45 | Atom Avg. RMSE Loss: 0.0498 | Bond Avg. RMSE Loss: 0.1965
# Epoch:  12/12 | Sample:     11/45 | Atom Avg. RMSE Loss: 0.0522 | Bond Avg. RMSE Loss: 0.2335
# Epoch:  12/12 | Sample:     21/45 | Atom Avg. RMSE Loss: 0.0515 | Bond Avg. RMSE Loss: 0.2400
# Epoch:  12/12 | Sample:     31/45 | Atom Avg. RMSE Loss: 0.0519 | Bond Avg. RMSE Loss: 0.2265
# Epoch:  12/12 | Sample:     41/45 | Atom Avg. RMSE Loss: 0.0504 | Bond Avg. RMSE Loss: 0.2256

# %%
# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
#plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Atom Autoencoder Training Losses for logs")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"./models/atom_autoencoder_losses_logs.png")
plt.show()

# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
#plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Bond Autoencoder Training Losses for logs")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"./models/bond_autoencoder_losses_logs.png")
plt.show()

# %% [markdown]
# ### GNN3D training

# %%
# GNN3D Training
atom_autoencoder = Autoencoder(154, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
 
mse_loss_fn = torch.nn.MSELoss()

gnn3d = GNN3D(atomic_vector_size=10, bond_vector_size=3, number_of_molecular_features=200, number_of_targets=1).to(device)

gnn_optimizer = torch.optim.Adam(gnn3d.parameters())
rmse_losses, mse_losses = train_gnn3d_model(gnn3d, train_samples, atom_autoencoder, bond_autoencoder, n_epochs=12, printstep=10, save_dir="./models/", dataset_name="logs")
# Out:
# Epoch:   0 | Samples:      0 | Avg. RMSE Loss: 1.6551 | Avg. MSE Loss: 2.7393
# Epoch:   0 | Samples:     10 | Avg. RMSE Loss: 0.4510 | Avg. MSE Loss: 0.4068
# Epoch:   0 | Samples:     20 | Avg. RMSE Loss: 0.4132 | Avg. MSE Loss: 0.3028
# Epoch:   0 | Samples:     30 | Avg. RMSE Loss: 0.3918 | Avg. MSE Loss: 0.2592
# Epoch:   0 | Samples:     40 | Avg. RMSE Loss: 0.3825 | Avg. MSE Loss: 0.2313
# Epoch:   1 | Samples:      0 | Avg. RMSE Loss: 0.9430 | Avg. MSE Loss: 0.8893
# Epoch:   1 | Samples:     10 | Avg. RMSE Loss: 0.4486 | Avg. MSE Loss: 0.2668
# Epoch:   1 | Samples:     20 | Avg. RMSE Loss: 0.3617 | Avg. MSE Loss: 0.1897
# Epoch:   1 | Samples:     30 | Avg. RMSE Loss: 0.3472 | Avg. MSE Loss: 0.1817
# Epoch:   1 | Samples:     40 | Avg. RMSE Loss: 0.3380 | Avg. MSE Loss: 0.1674
# Epoch:   2 | Samples:      0 | Avg. RMSE Loss: 0.8010 | Avg. MSE Loss: 0.6416
# Epoch:   2 | Samples:     10 | Avg. RMSE Loss: 0.4099 | Avg. MSE Loss: 0.2224
# Epoch:   2 | Samples:     20 | Avg. RMSE Loss: 0.3286 | Avg. MSE Loss: 0.1581
# Epoch:   2 | Samples:     30 | Avg. RMSE Loss: 0.3184 | Avg. MSE Loss: 0.1528
# Epoch:   2 | Samples:     40 | Avg. RMSE Loss: 0.3101 | Avg. MSE Loss: 0.1408
# Epoch:   3 | Samples:      0 | Avg. RMSE Loss: 0.7430 | Avg. MSE Loss: 0.5521
# Epoch:   3 | Samples:     10 | Avg. RMSE Loss: 0.3735 | Avg. MSE Loss: 0.1862
# Epoch:   3 | Samples:     20 | Avg. RMSE Loss: 0.2997 | Avg. MSE Loss: 0.1332
# Epoch:   3 | Samples:     30 | Avg. RMSE Loss: 0.2916 | Avg. MSE Loss: 0.1276
# Epoch:   3 | Samples:     40 | Avg. RMSE Loss: 0.2844 | Avg. MSE Loss: 0.1183
# Epoch:   4 | Samples:      0 | Avg. RMSE Loss: 0.6998 | Avg. MSE Loss: 0.4897
# Epoch:   4 | Samples:     10 | Avg. RMSE Loss: 0.3394 | Avg. MSE Loss: 0.1551
# Epoch:   4 | Samples:     20 | Avg. RMSE Loss: 0.2729 | Avg. MSE Loss: 0.1130
# Epoch:   4 | Samples:     30 | Avg. RMSE Loss: 0.2668 | Avg. MSE Loss: 0.1067
# Epoch:   4 | Samples:     40 | Avg. RMSE Loss: 0.2607 | Avg. MSE Loss: 0.0998
# Epoch:   5 | Samples:      0 | Avg. RMSE Loss: 0.6582 | Avg. MSE Loss: 0.4332
# Epoch:   5 | Samples:     10 | Avg. RMSE Loss: 0.3068 | Avg. MSE Loss: 0.1300
# Epoch:   5 | Samples:     20 | Avg. RMSE Loss: 0.2497 | Avg. MSE Loss: 0.0978
# Epoch:   5 | Samples:     30 | Avg. RMSE Loss: 0.2467 | Avg. MSE Loss: 0.0915
# Epoch:   5 | Samples:     40 | Avg. RMSE Loss: 0.2407 | Avg. MSE Loss: 0.0856
# Epoch:   6 | Samples:      0 | Avg. RMSE Loss: 0.6227 | Avg. MSE Loss: 0.3878
# Epoch:   6 | Samples:     10 | Avg. RMSE Loss: 0.2775 | Avg. MSE Loss: 0.1107
# Epoch:   6 | Samples:     20 | Avg. RMSE Loss: 0.2281 | Avg. MSE Loss: 0.0863
# Epoch:   6 | Samples:     30 | Avg. RMSE Loss: 0.2280 | Avg. MSE Loss: 0.0801
# Epoch:   6 | Samples:     40 | Avg. RMSE Loss: 0.2221 | Avg. MSE Loss: 0.0749
# Epoch:   7 | Samples:      0 | Avg. RMSE Loss: 0.5832 | Avg. MSE Loss: 0.3401
# Epoch:   7 | Samples:     10 | Avg. RMSE Loss: 0.2488 | Avg. MSE Loss: 0.0938
# Epoch:   7 | Samples:     20 | Avg. RMSE Loss: 0.2089 | Avg. MSE Loss: 0.0768
# Epoch:   7 | Samples:     30 | Avg. RMSE Loss: 0.2106 | Avg. MSE Loss: 0.0711
# Epoch:   7 | Samples:     40 | Avg. RMSE Loss: 0.2057 | Avg. MSE Loss: 0.0663
# Epoch:   8 | Samples:      0 | Avg. RMSE Loss: 0.5563 | Avg. MSE Loss: 0.3094
# Epoch:   8 | Samples:     10 | Avg. RMSE Loss: 0.2262 | Avg. MSE Loss: 0.0819
# Epoch:   8 | Samples:     20 | Avg. RMSE Loss: 0.1982 | Avg. MSE Loss: 0.0706
# Epoch:   8 | Samples:     30 | Avg. RMSE Loss: 0.1996 | Avg. MSE Loss: 0.0654
# Epoch:   8 | Samples:     40 | Avg. RMSE Loss: 0.1945 | Avg. MSE Loss: 0.0602
# Epoch:   9 | Samples:      0 | Avg. RMSE Loss: 0.5285 | Avg. MSE Loss: 0.2793
# Epoch:   9 | Samples:     10 | Avg. RMSE Loss: 0.2067 | Avg. MSE Loss: 0.0697
# Epoch:   9 | Samples:     20 | Avg. RMSE Loss: 0.1926 | Avg. MSE Loss: 0.0655
# Epoch:   9 | Samples:     30 | Avg. RMSE Loss: 0.1904 | Avg. MSE Loss: 0.0600
# Epoch:   9 | Samples:     40 | Avg. RMSE Loss: 0.1849 | Avg. MSE Loss: 0.0547
# Epoch:  10 | Samples:      0 | Avg. RMSE Loss: 0.5167 | Avg. MSE Loss: 0.2670
# Epoch:  10 | Samples:     10 | Avg. RMSE Loss: 0.1918 | Avg. MSE Loss: 0.0628
# Epoch:  10 | Samples:     20 | Avg. RMSE Loss: 0.1861 | Avg. MSE Loss: 0.0615
# Epoch:  10 | Samples:     30 | Avg. RMSE Loss: 0.1818 | Avg. MSE Loss: 0.0558
# Epoch:  10 | Samples:     40 | Avg. RMSE Loss: 0.1760 | Avg. MSE Loss: 0.0503
# Epoch:  11 | Samples:      0 | Avg. RMSE Loss: 0.4876 | Avg. MSE Loss: 0.2378
# Epoch:  11 | Samples:     10 | Avg. RMSE Loss: 0.1802 | Avg. MSE Loss: 0.0566
# Epoch:  11 | Samples:     20 | Avg. RMSE Loss: 0.1809 | Avg. MSE Loss: 0.0575
# Epoch:  11 | Samples:     30 | Avg. RMSE Loss: 0.1735 | Avg. MSE Loss: 0.0516
# Epoch:  11 | Samples:     40 | Avg. RMSE Loss: 0.1681 | Avg. MSE Loss: 0.0464

# %%
# Assuming rmse_losses is the list of RMSE losses obtained from training
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(rmse_losses)+1), rmse_losses, marker='o', linestyle='-', color='b', label='Avg. RMSE Loss')
plt.title(f"GNN3D Training Losses for logs")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"./models/gnn3d_rmse_losses_logs.png")
plt.show()

# %% [markdown]
# ## Testing

# %%
evaluate_gnn3d_model(
    gnn3d, 
    test_samples, 
    atom_autoencoder, 
    bond_autoencoder
)
# Out:
# Evaluation Results:
# Avg. RMSE Loss: 0.4796
# Avg. MSE Loss: 0.2465
# (0.4796247931888965, 0.24654071927070617)

# %% [markdown]
# ## Know your predictions (KYP)

# %%
def molecule_from_smiles(smiles):
    """Convert SMILES to rdkit.Mol with 2D coordinates"""
    molecule = Chem.MolFromSmiles(smiles, sanitize=False)
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        Chem.SanitizeMol(molecule, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ flag)

    Chem.AssignStereochemistry(molecule, cleanIt=True, force=True)
    return molecule

def smi2conf_etkdg(smiles):
    '''Convert SMILES to rdkit.Mol with 3D coordinates
       Use Experimental Torsion angles Knowledge-based Distance Geometry ETKDGv3
       method - version 3 (small rings)
       params.numThreads = 0 uses max no. of threads allowed on a conputer
    '''
    params = Chem.rdDistGeom.srETKDGv3()
    params.randomSeed = 12412
    params.clearConfs = True
    params.numThreads = 0
    
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        mol = Chem.AddHs(mol)
        AllChem.EmbedMolecule(mol)
        AllChem.EmbedMultipleConfs(mol, numConfs=500, params=params)
        
        return mol
    else:
        return None



# Set the model in evaluation mode
gnn3d.eval()

# List to store predictions
predictions = []

# Iterate over test samples
for molecule in test_samples:
    # Assuming process_molecule function converts each molecule list to tensor
    molecule_data, _ = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
    
    if molecule_data is None:
        continue  # Skip if molecule_data is None
    
    # Move molecule_data to device if necessary
    molecule_data = [elem.to(device) for elem in molecule_data]
    
    # Forward pass
    with torch.no_grad():
        prediction = gnn3d(molecule_data)
    
    # Extract prediction, assuming single scalar output prediction
    prediction_value = prediction.item()
    
    # Store prediction
    predictions.append(prediction_value)




molecules = [molecule_from_smiles(dataset.smiles.values[i]) for i in range(len(test_samples))]
y_true = [dataset.logS.values[i] for i in range(len(test_samples))]
y_pred = [predictions[i] for i in range(len(test_samples))]

legends = [f"y_true/y_pred = {y_true[i]:.2f}/{y_pred[i]:.2f}" for i in range(len(y_true))]
MolsToGridImage(molecules, molsPerRow=4, legends=legends)

# %% [markdown]
# ## Future task: What is so unique about dihedral angles?
