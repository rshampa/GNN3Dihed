# %% [markdown]
# ## Know your libraries (KYL)

# %%
from dataset import QM9Dataset,LogSDataset,LogPDataset,FreeSolvDataset,ESOLDataset
from dataset import *
import numpy as np
np.random.seed(424345)
import pandas as pd
from utils import *
import torch
from tqdm import tqdm
from model import Autoencoder # Simply importing the autoencoder model module from the model.py file
from model import GNN3D

import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import MolsToGridImage

import os
import sys
datadir="../data/esol/"
modeldir="./models/esol/"
# Create datadir and modeldir folders if they don't exist
if not os.path.exists(datadir):
    os.makedirs(datadir)
    
if not os.path.exists(modeldir):
    os.makedirs(modeldir)
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Split your dataset (SYD)

# %%
# Load dataset from CSV
dataset = pd.read_csv(datadir+"esol.csv")

# Split dataset into train and test
train_dataset, test_dataset = split_dataset(dataset, 0.8)

# Write train_dataset and test_dataset to CSV files
train_dataset.to_csv(datadir+"train.csv", index=False)
test_dataset.to_csv(datadir+"test.csv", index=False)

print("Train and test datasets saved successfully.")
# Out:
# Train and test datasets saved successfully.

# %% [markdown]
# ## Process your data (PYD)

# %%
train_samples = ESOLDataset(datadir+"train")
print(train_samples)
print("===================================")
test_samples = ESOLDataset(datadir+"test")
print(test_samples)
# Out:
# Loading Raw Data and processing it
# Initializing Molecular Representation Generator
# Loading Molecular Representations
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
#   0%|▏                                                                                                                                                           | 1/902 [00:00<09:08,  1.64it/s][17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:38] DEPRECATION WARNING: please use MorganGenerator
# [17:49:40] DEPRECATION WARNING: please use MorganGenerator
#   0%|▎                                                                                                                                                           | 2/902 [00:02<16:31,  1.10s/it][17:49:40] DEPRECATION WARNING: please use MorganGenerator
# [17:49:40] DEPRECATION WARNING: please use MorganGenerator
# [17:49:40] DEPRECATION WARNING: please use MorganGenerator
#   0%|▌                                                                                                                                                           | 3/902 [00:02<11:18,  1.32it/s][17:49:40] DEPRECATION WARNING: please use MorganGenerator
# [17:49:40] DEPRECATION WARNING: please use MorganGenerator
# [17:49:41] DEPRECATION WARNING: please use MorganGenerator
# [17:49:41] DEPRECATION WARNING: please use MorganGenerator
# [17:49:41] DEPRECATION WARNING: please use MorganGenerator
#   0%|▋                                                                                                                                                           | 4/902 [00:03<12:19,  1.21it/s][17:49:41] DEPRECATION WARNING: please use MorganGenerator
#   1%|▊                                                                                                                                                           | 5/902 [00:03<09:03,  1.65it/s][17:49:41] DEPRECATION WARNING: please use MorganGenerator
# [17:49:41] DEPRECATION WARNING: please use MorganGenerator
# [17:49:41] DEPRECATION WARNING: please use MorganGenerator
# [17:49:41] DEPRECATION WARNING: please use MorganGenerator
# [17:49:41] DEPRECATION WARNING: please use MorganGenerator
#   1%|█▏                                                                                                                                                          | 7/902 [00:03<05:46,  2.58it/s][17:49:42] DEPRECATION WARNING: please use MorganGenerator
# [17:49:42] DEPRECATION WARNING: please use MorganGenerator
# [17:49:42] DEPRECATION WARNING: please use MorganGenerator
# [17:49:42] DEPRECATION WARNING: please use MorganGenerator
#   1%|█▍                                                                                                                                                          | 8/902 [00:04<05:29,  2.71it/s][17:49:42] DEPRECATION WARNING: please use MorganGenerator
# [17:49:42] DEPRECATION WARNING: please use MorganGenerator
# [17:49:43] DEPRECATION WARNING: please use MorganGenerator
#   1%|█▌                                                                                                                                                          | 9/902 [00:04<06:50,  2.18it/s][17:49:43] DEPRECATION WARNING: please use MorganGenerator
# [17:49:43] DEPRECATION WARNING: please use MorganGenerator
# [17:49:43] DEPRECATION WARNING: please use MorganGenerator
# [17:49:43] DEPRECATION WARNING: please use MorganGenerator
# [17:49:43] DEPRECATION WARNING: please use MorganGenerator
#   1%|█▉                                                                                                                                                         | 11/902 [00:05<05:18,  2.80it/s][17:49:43] DEPRECATION WARNING: please use MorganGenerator
# [17:49:43] DEPRECATION WARNING: please use MorganGenerator
# [17:49
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████           | 210/226 [04:23<00:15,  1.06it/s][18:11:36] DEPRECATION WARNING: please use MorganGenerator
# [18:11:36] DEPRECATION WARNING: please use MorganGenerator
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊          | 211/226 [04:24<00:13,  1.08it/s][18:11:37] DEPRECATION WARNING: please use MorganGenerator
# [18:11:37] DEPRECATION WARNING: please use MorganGenerator
# [18:11:37] DEPRECATION WARNING: please use MorganGenerator
# [18:11:39] DEPRECATION WARNING: please use MorganGenerator
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍         | 212/226 [04:27<00:19,  1.36s/it][18:11:39] DEPRECATION WARNING: please use MorganGenerator
# [18:11:39] DEPRECATION WARNING: please use MorganGenerator
# [18:11:43] DEPRECATION WARNING: please use MorganGenerator
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 213/226 [04:30<00:24,  1.85s/it][18:11:43] DEPRECATION WARNING: please use MorganGenerator
# [18:11:43] DEPRECATION WARNING: please use MorganGenerator
# [18:11:43] DEPRECATION WARNING: please use MorganGenerator
# [18:11:43] DEPRECATION WARNING: please use MorganGenerator
# [18:11:43] DEPRECATION WARNING: please use MorganGenerator
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌       | 215/226 [04:32<00:17,  1.58s/it][18:11:45] DEPRECATION WARNING: please use MorganGenerator
# [18:11:45] DEPRECATION WARNING: please use MorganGenerator
# [18:11:45] DEPRECATION WARNING: please use MorganGenerator
# [18:11:46] DEPRECATION WARNING: please use MorganGenerator
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏      | 216/226 [04:33<00:14,  1.46s/it][18:11:46] DEPRECATION WARNING: please use MorganGenerator
# [18:11:46] DEPRECATION WARNING: please use MorganGenerator
# [18:11:46] DEPRECATION WARNING: please use MorganGenerator
# [18:11:46] DEPRECATION WARNING: please use MorganGenerator
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊      | 217/226 [04:34<00:10,  1.14s/it][18:11:46] DEPRECATION WARNING: please use MorganGenerator
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌     | 218/226 [04:34<00:08,  1.07s/it][18:11:47] DEPRECATION WARNING: please use MorganGenerator
# [18:11:47] DEPRECATION WARNING: please use MorganGenerator
# [18:11:47] DEPRECATION WARNING: please use MorganGenerator
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 226/226 [06:20<00:00,  1.68s/it]
# Saving data.
# Dataset Name: ESOL
# Number of Molecules Loaded: 226

# %% [markdown]
# ## Know your featues (KYF)

# %%
# Printing out the dimensions of all of these features with a description of what each feature is
print(f"Atomic Features: {(train_samples[0])[0].shape} - This represents the atomic features of the molecule")
print(f"Bond Features: {(train_samples[0])[1].shape} - This represents the bond features of the molecule")
print(f"Angle Features: {(train_samples[0])[2].shape} - This represents the angle features of the molecule")
print(f"Dihedral Features: {(train_samples[0])[3].shape} - This represents the dihedral features of the molecule")
print(f"Global Molecular Features: {(train_samples[0])[4].shape} - This represents the global molecular features of the molecule")
print(f"Bond Indices: {(train_samples[0])[5].shape} - This represents the bond indices of the molecule")
print(f"Angle Indices: {(train_samples[0])[6].shape} - This represents the angle indices of the molecule")
print(f"Dihedral Indices: {(train_samples[0])[7].shape} - This represents the dihedral indices of the molecule")
print(f"Target: {(train_samples[0])[8].shape} - This represents the target of the molecule")
# Out:
# Atomic Features: torch.Size([10, 56]) - This represents the atomic features of the molecule
# Bond Features: torch.Size([20, 10]) - This represents the bond features of the molecule
# Angle Features: torch.Size([28]) - This represents the angle features of the molecule
# Dihedral Features: torch.Size([32]) - This represents the dihedral features of the molecule
# Global Molecular Features: torch.Size([200]) - This represents the global molecular features of the molecule
# Bond Indices: torch.Size([20, 2]) - This represents the bond indices of the molecule
# Angle Indices: torch.Size([28, 2]) - This represents the angle indices of the molecule
# Dihedral Indices: torch.Size([32, 2]) - This represents the dihedral indices of the molecule
# Target: torch.Size([1]) - This represents the target of the molecule

# %% [markdown]
# ## Know your modules (KYM)

# %%
def train_autoencoder_model(samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train Autoencoder: Atom and bond"""
    # Set the model in training mode
    atom_autoencoder.train()
    bond_autoencoder.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)

    # Lists to store losses
    avg_atom_rmse_losses = []
    avg_bond_rmse_losses = []

    for epoch_i in range(n_epochs):
        avg_atom_rmse_loss = 0
        avg_bond_rmse_loss = 0
        total_samples = 0
        
        for i, molecule in enumerate(samples):
            atom_features = molecule[0].to(device)
            bond_features = molecule[1].to(device)
            
            # Forward pass
            atom_features_reconstructed = atom_autoencoder(atom_features)
            bond_features_reconstructed = bond_autoencoder(bond_features)
            
            # Calculating loss
            atom_loss = mse_loss_fn(atom_features_reconstructed, atom_features)
            bond_loss = mse_loss_fn(bond_features_reconstructed, bond_features)
            
            # Backward pass and optimization step
            atom_optimizer.zero_grad()
            bond_optimizer.zero_grad()
            atom_loss.backward()
            bond_loss.backward()
            atom_optimizer.step()
            bond_optimizer.step()
            
            # Calculating average loss
            avg_atom_rmse_loss = (avg_atom_rmse_loss * total_samples + torch.sqrt(atom_loss).item()) / (total_samples + 1)
            avg_bond_rmse_loss = (avg_bond_rmse_loss * total_samples + torch.sqrt(bond_loss).item()) / (total_samples + 1)           
            total_samples += 1

            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i + 1:>3}/{n_epochs} | Samples: {i + 1:>6}/{len(samples)} | Atom Avg. RMSE Loss: {avg_atom_rmse_loss:.4f} | Bond Avg. RMSE Loss: {avg_bond_rmse_loss:.4f}")
        
        # Append average losses for the epoch to lists
        avg_atom_rmse_losses.append(avg_atom_rmse_loss)
        avg_bond_rmse_losses.append(avg_bond_rmse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"autoencoder_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg Atom RMSE Loss\tAvg Bond RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i+1}\t{avg_atom_rmse_losses[epoch_i]}\t{avg_bond_rmse_losses[epoch_i]}\n")

    # Save model state
    torch.save(atom_autoencoder.state_dict(), f"{save_dir}atom_autoencoder_{dataset_name}.pth")
    torch.save(bond_autoencoder.state_dict(), f"{save_dir}bond_autoencoder_{dataset_name}.pth")
    
    return avg_atom_rmse_losses, avg_bond_rmse_losses
    



def process_molecule(molecule, atom_autoencoder, bond_autoencoder):
    """Separate input features and target"""
    # Ensure molecule has at least 8 elements
    if len(molecule) < 8:
        return None, None
    
    target = molecule[8].to(device)  # Assuming target is the 9th element (index 8)
    # Assuming first 8 elements are molecule graph input features:
    # atomic_features, bond_features, angle_features, dihedral_features, 
    # global_molecular_features, bond_indices, angle_indices,  dihedral_indices    
    molecule_data = [mol_elem.to(device) for mol_elem in molecule[:8]]
    
    # Putting latent atomic and bond features through encoders
    molecule_data[0] = atom_autoencoder.encode(molecule_data[0])
    molecule_data[1] = bond_autoencoder.encode(molecule_data[1])
    
    return molecule_data, target




def train_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train GNN3D"""
    # Set the model in training mode
    gnn3d.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)
   
    # Lists to store losses
    avg_rmse_losses = []
    avg_mse_losses = []
    avg_mae_losses = []

    for epoch_i in range(n_epochs):
        avg_rmse_loss = 0
        avg_mse_loss = 0
        avg_mae_loss = 0
        total_samples = 0
        
        for i in tqdm(range(len(samples)), desc='Processing samples'):
            molecule_data, target = process_molecule(samples[i], atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)
            
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            lossl1 = mae_loss_fn(prediction, target)
            
            # Backward pass
            gnn_optimizer.zero_grad()
            loss.backward()
            lossl1.backward()
            gnn_optimizer.step()
            
            # Calculating average loss
            avg_rmse_loss = (avg_rmse_loss * total_samples + torch.sqrt(loss).item()) / (total_samples + 1)
            avg_mse_loss = (avg_mse_loss * total_samples + loss.item()) / (total_samples + 1)
            avg_mae_loss = (avg_mae_loss * total_samples + lossl1.item()) / (total_samples + 1)
            total_samples += 1
            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3} | Samples: {i:>6}/{len(samples)} | Avg. RMSE Loss: {avg_rmse_loss:.4f} | Avg. MSE Loss: {avg_mse_loss:.4f} | Avg. MAE Loss: {avg_mae_loss:.4f}")

                # Append average losses for the epoch to lists
        avg_rmse_losses.append(avg_rmse_loss)
        avg_mse_losses.append(avg_mse_loss)
        avg_mae_losses.append(avg_mae_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"gnn3d_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch\tAvg RMSE Loss\tAvg RMSE Loss\tAvg MAE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i+1}\t{avg_rmse_losses[epoch_i]}\t{avg_mse_losses[epoch_i]}\t{avg_mae_losses[epoch_i]}\n")

    # Save model state
    torch.save(gnn3d.state_dict(), f"{save_dir}gnn3d_{dataset_name}.pth")
    
    return avg_rmse_losses, avg_mse_losses, avg_mae_losses




def evaluate_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder):
    """Evaluate GNN3D"""
    # Set the model in evaluation mode
    gnn3d.eval()

    avg_rmse_loss = 0
    avg_mse_loss = 0
    avg_mae_loss = 0
    total_samples = 0
    
    with torch.no_grad():
        for i, molecule in enumerate(samples):
            molecule_data, target = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)
            
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
            lossl1 = mae_loss_fn(prediction, target)
            
            # Accumulate losses
            avg_rmse_loss += (torch.sqrt(loss).item())
            avg_mse_loss += loss.item()
            avg_mae_loss += lossl1.item()
            total_samples += 1
    
    # Calculate average losses
    avg_rmse_loss /= total_samples
    avg_mse_loss /= total_samples
    avg_mae_loss /= total_samples
    
    print(f"Evaluation Results:")
    print(f"Avg. RMSE Loss: {avg_rmse_loss:.4f}")
    print(f"Avg. MSE Loss: {avg_mse_loss:.4f}")
    print(f"Avg. MAE Loss: {avg_mae_loss:.4f}")
    
    return avg_rmse_loss, avg_mse_loss, avg_mae_loss

# %% [markdown]
# ## Training

# %% [markdown]
# ### Autoencoder training

# %%
atom_autoencoder = Autoencoder(56, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
atom_optimizer = torch.optim.Adam(atom_autoencoder.parameters())
bond_optimizer = torch.optim.Adam(bond_autoencoder.parameters())

atom_losses, bond_losses = train_autoencoder_model(train_samples, atom_autoencoder, bond_autoencoder, n_epochs=20, printstep=500, save_dir=modeldir, dataset_name="logp")
# Out:
# Epoch:   1/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.3577 | Bond Avg. RMSE Loss: 0.5989
# Epoch:   1/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.1625 | Bond Avg. RMSE Loss: 0.3279
# Epoch:   2/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.1214 | Bond Avg. RMSE Loss: 0.0876
# Epoch:   2/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0641 | Bond Avg. RMSE Loss: 0.0944
# Epoch:   3/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0835 | Bond Avg. RMSE Loss: 0.0710
# Epoch:   3/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0542 | Bond Avg. RMSE Loss: 0.0720
# Epoch:   4/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0500 | Bond Avg. RMSE Loss: 0.0608
# Epoch:   4/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0488 | Bond Avg. RMSE Loss: 0.0509
# Epoch:   5/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0455 | Bond Avg. RMSE Loss: 0.0265
# Epoch:   5/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0465 | Bond Avg. RMSE Loss: 0.0326
# Epoch:   6/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0423 | Bond Avg. RMSE Loss: 0.0156
# Epoch:   6/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0457 | Bond Avg. RMSE Loss: 0.0216
# Epoch:   7/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0395 | Bond Avg. RMSE Loss: 0.0101
# Epoch:   7/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0426 | Bond Avg. RMSE Loss: 0.0177
# Epoch:   8/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0376 | Bond Avg. RMSE Loss: 0.0083
# Epoch:   8/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0415 | Bond Avg. RMSE Loss: 0.0171
# Epoch:   9/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0373 | Bond Avg. RMSE Loss: 0.0120
# Epoch:   9/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0406 | Bond Avg. RMSE Loss: 0.0174
# Epoch:  10/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0369 | Bond Avg. RMSE Loss: 0.0113
# Epoch:  10/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0405 | Bond Avg. RMSE Loss: 0.0177
# Epoch:  11/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0366 | Bond Avg. RMSE Loss: 0.0079
# Epoch:  11/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0395 | Bond Avg. RMSE Loss: 0.0152
# Epoch:  12/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0366 | Bond Avg. RMSE Loss: 0.0122
# Epoch:  12/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0395 | Bond Avg. RMSE Loss: 0.0156
# Epoch:  13/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0363 | Bond Avg. RMSE Loss: 0.0070
# Epoch:  13/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0390 | Bond Avg. RMSE Loss: 0.0139
# Epoch:  14/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0380 | Bond Avg. RMSE Loss: 0.0069
# Epoch:  14/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0390 | Bond Avg. RMSE Loss: 0.0141
# Epoch:  15/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0361 | Bond Avg. RMSE Loss: 0.0069
# Epoch:  15/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0391 | Bond Avg. RMSE Loss: 0.0142
# Epoch:  16/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0370 | Bond Avg. RMSE Loss: 0.0084
# Epoch:  16/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0392 | Bond Avg. RMSE Loss: 0.0148
# Epoch:  17/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0362 | Bond Avg. RMSE Loss: 0.0056
# Epoch:  17/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0395 | Bond Avg. RMSE Loss: 0.0126
# Epoch:  18/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0361 | Bond Avg. RMSE Loss: 0.0137
# Epoch:  18/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0388 | Bond Avg. RMSE Loss: 0.0161
# Epoch:  19/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0363 | Bond Avg. RMSE Loss: 0.0101
# Epoch:  19/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0390 | Bond Avg. RMSE Loss: 0.0139
# Epoch:  20/20 | Samples:      1/902 | Atom Avg. RMSE Loss: 0.0363 | Bond Avg. RMSE Loss: 0.0185
# Epoch:  20/20 | Samples:    501/902 | Atom Avg. RMSE Loss: 0.0388 | Bond Avg. RMSE Loss: 0.0127

# %%
# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
#plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Atom Autoencoder Training Losses for logp")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}atom_autoencoder_losses_logp.png")
plt.show()

# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
#plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Bond Autoencoder Training Losses for logp")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}bond_autoencoder_losses_logp.png")
plt.show()

# %% [markdown]
# ### GNN3D training

# %%
atom_autoencoder = Autoencoder(56, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
mae_loss_fn = torch.nn.L1Loss()
gnn3d = GNN3D(atomic_vector_size=10, bond_vector_size=3, number_of_molecular_features=200, number_of_targets=1).to(device)
gnn_optimizer = torch.optim.Adam(gnn3d.parameters())
rmse_losses, mse_losses, mae_losses = train_gnn3d_model(gnn3d, train_samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=500, save_dir=modeldir, dataset_name="logp")
# Out:
# Processing samples:   0%|                                                                                                                                                | 0/902 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 7
#       5 gnn3d = GNN3D(atomic_vector_size=10, bond_vector_size=3, number_of_molecular_features=200, number_of_targets=1).to(device)
#       6 gnn_optimizer = torch.optim.Adam(gnn3d.parameters())
# ----> 7 rmse_losses, mse_losses, mae_losses = train_gnn3d_model(gnn3d, train_samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=500, save_dir=modeldir, dataset_name="logp")
#
# Cell In[15], line 123, in train_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder, n_epochs, printstep, save_dir, dataset_name)
#     121 gnn_optimizer.zero_grad()
#     122 loss.backward()
# --> 123 lossl1.backward()
#     124 gnn_optimizer.step()
#     126 # Calculating average loss
#
# File ~/software/anaconda3/envs/py312/lib/python3.12/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/software/anaconda3/envs/py312/lib/python3.12/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# RuntimeError: Trying to backward through the graph a second time (or directly access saved tensors after they have already been freed). Saved intermediate values of the graph are freed when you call .backward() or autograd.grad(). Specify retain_graph=True if you need to backward through the graph a second time or if you need to access saved tensors after calling backward.

# %%
# Assuming rmse_losses is the list of RMSE losses obtained from training
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(rmse_losses)+1), rmse_losses, marker='o', linestyle='-', color='b', label='Avg. RMSE Loss')
plt.title(f"GNN3D Training Losses for logp")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}gnn3d_rmse_losses_logp.png")
plt.show()

# %% [markdown]
# ## Testing

# %%
evaluate_gnn3d_model(
    gnn3d, 
    test_samples, 
    atom_autoencoder, 
    bond_autoencoder
)
# Out:
# Evaluation Results:
# Avg. RMSE Loss: 0.4474
# Avg. MSE Loss: 0.3504
# (0.44740318681682106, 0.3503806218500529)

# %% [markdown]
# ## Know your predictions (KYP)

# %%
def molecule_from_smiles(smiles):
    """Convert SMILES to rdkit.Mol with 2D coordinates"""
    molecule = Chem.MolFromSmiles(smiles, sanitize=False)
    flag = Chem.SanitizeMol(molecule, catchErrors=True)
    if flag != Chem.SanitizeFlags.SANITIZE_NONE:
        Chem.SanitizeMol(molecule, sanitizeOps=Chem.SanitizeFlags.SANITIZE_ALL ^ flag)

    Chem.AssignStereochemistry(molecule, cleanIt=True, force=True)
    return molecule

def smi2conf_etkdg(smiles):
    '''Convert SMILES to rdkit.Mol with 3D coordinates
       Use Experimental Torsion angles Knowledge-based Distance Geometry ETKDGv3
       method - version 3 (small rings)
       params.numThreads = 0 uses max no. of threads allowed on a conputer
    '''
    params = Chem.rdDistGeom.srETKDGv3()
    params.randomSeed = 12412
    params.clearConfs = True
    params.numThreads = 0
    
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        mol = Chem.AddHs(mol)
        AllChem.EmbedMolecule(mol)
        AllChem.EmbedMultipleConfs(mol, numConfs=500, params=params)
        
        return mol
    else:
        return None



# Set the model in evaluation mode
gnn3d.eval()

# List to store predictions
predictions = []

# Iterate over test samples
for molecule in test_samples:
    # Assuming process_molecule function converts each molecule list to tensor
    molecule_data, _ = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
    
    if molecule_data is None:
        continue  # Skip if molecule_data is None
    
    # Move molecule_data to device if necessary
    molecule_data = [elem.to(device) for elem in molecule_data]
    
    # Forward pass
    with torch.no_grad():
        prediction = gnn3d(molecule_data)
    
    # Extract prediction, assuming single scalar output prediction
    prediction_value = prediction.item()
    
    # Store prediction
    predictions.append(prediction_value)



# Load test_samples from CSV
dataset = pd.read_csv(datadir+"test.csv")
molecules = [molecule_from_smiles(dataset.smiles.values[i]) for i in range(len(test_samples))]
y_true = [dataset.logSolubility.values[i] for i in range(len(test_samples))]
y_pred = [predictions[i] for i in range(len(test_samples))]

legends = [f"y_true/y_pred = {y_true[i]:.2f}/{y_pred[i]:.2f}" for i in range(len(y_true))]
MolsToGridImage(molecules, molsPerRow=5, maxMols=len(test_samples)-175,legends=legends)
# Out:
# /Users/shampa/software/anaconda3/envs/py312/lib/python3.12/site-packages/rdkit/Chem/Draw/IPythonConsole.py:261: UserWarning: Truncating the list of molecules to be displayed to 51. Change the maxMols value to display more.
#   warnings.warn(

# %% [markdown]
# ## Future task: What is so unique about dihedral angles?
