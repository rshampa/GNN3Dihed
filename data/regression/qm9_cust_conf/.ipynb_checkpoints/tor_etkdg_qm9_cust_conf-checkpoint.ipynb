# %%
# %matplotlib inline
import os
import sys
sys.path.append('/Users/shampa/software/anaconda3/envs/py312/lib/python3.12/site-packages')
import matplotlib.pyplot as plt

from ipywidgets import interact,fixed,IntSlider
import ipywidgets

from io import BytesIO
import pandas as pd
import numpy as np
from rdkit.Chem import PandasTools

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import DataStructs
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import rdRGroupDecomposition
from rdkit.Chem import rdMolTransforms

from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules
from rdkit.Chem import Draw
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions #Only needed if modifying defaults

DrawingOptions.bondLineWidth=1.8
IPythonConsole.ipython_useSVG=True
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.warning')
import rdkit
import py3Dmol
print(rdkit.__version__)
# Out:
# 2024.03.3

# %%
def MolTo3DView(mol, size=(300, 300), style="stick", surface=False, opacity=0.5):
    """Draw molecule in 3D
    
    Args:
    ----
        mol: rdMol, molecule to show
        size: tuple(int, int), canvas size
        style: str, type of drawing molecule
               style can be 'line', 'stick', 'sphere', 'carton'
        surface, bool, display SAS
        opacity, float, opacity of surface, range 0.0-1.0
    Return:
    ----
        viewer: py3Dmol.view, a class for constructing embedded 3Dmol.js views in ipython notebooks.
    """
    assert style in ('line', 'stick', 'sphere', 'carton')
    mblock = Chem.MolToMolBlock(mol)
    viewer = py3Dmol.view(width=size[0], height=size[1])
    viewer.addModel(mblock, 'mol')
    viewer.setStyle({style:{}})
    if surface:
        viewer.addSurface(py3Dmol.SAS, {'opacity': opacity})
    viewer.zoomTo()
    return viewer

# %%
def smi2conf_etkdg(smiles):
    '''Convert SMILES to rdkit.Mol with 3D coordinates
       Use Experimental Torsion angles Knowledge-based Distance Geometry ETKDGv3
       method - version 3 (small rings)
       params.numThreads = 0 uses max no. of threads allowed on a conputer
    '''
    params = Chem.rdDistGeom.srETKDGv3()
    params.randomSeed = 12412
    params.clearConfs = True
    params.numThreads = 0
    
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        mol = Chem.AddHs(mol)
        AllChem.EmbedMolecule(mol)
        AllChem.EmbedMultipleConfs(mol, numConfs=10, params=params)
        
        return mol
    else:
        return None

# %%
def enumerateTorsions(mol):
    torsionList = []
    
    # Iterate through all bonds in the molecule
    for bond in mol.GetBonds():
        beginAtomIdx = bond.GetBeginAtomIdx()
        endAtomIdx = bond.GetEndAtomIdx()
        
        # Get the atoms connected by the current bond
        beginAtom = mol.GetAtomWithIdx(beginAtomIdx)
        endAtom = mol.GetAtomWithIdx(endAtomIdx)
        
        # Skip bonds involving terminal atoms with valency 1
        if beginAtom.GetExplicitValence() == 1 or endAtom.GetExplicitValence() == 1 or beginAtom.GetExplicitValence() == 2 or endAtom.GetExplicitValence() == 2 or beginAtom.GetExplicitValence() == 3 or endAtom.GetExplicitValence() == 3:
            continue
        
        # Get neighboring atoms for beginAtom and endAtom to form torsions
        for neighbor1 in beginAtom.GetNeighbors():
            if neighbor1.GetIdx() != endAtom.GetIdx():
                atom1 = neighbor1
                break
        for neighbor2 in endAtom.GetNeighbors():
            if neighbor2.GetIdx() != beginAtom.GetIdx():
                atom4 = neighbor2
                break
        
        # Append torsion angle indices (atom indices) to the torsionList
        torsionList.append((atom1.GetIdx(), beginAtomIdx, endAtomIdx, atom4.GetIdx()))
    
    return torsionList

# %% [markdown]
# ## TESTing for a single SMILES

# %%
smiles = 'C=CC#N'
mol = Chem.MolFromSmiles(smiles)
mol_h = Chem.AddHs(mol)
params = Chem.rdDistGeom.srETKDGv3()
params.randomSeed = 12412
params.clearConfs = True

torsionList = enumerateTorsions(mol_h)
print(f"List of torsions: {torsionList}")


cids = AllChem.EmbedMultipleConfs(mol_h, numConfs=100, params=params)

atoms=[a for a in mol_h.GetAtoms()]
for a in atoms:
    print( a.GetIdx(), a.GetSymbol() )


bonds = [(x.GetBeginAtomIdx(), x.GetEndAtomIdx()) for x in mol_h.GetBonds()]
print(bonds)


for cidx in cids:
    print(f"Conformer ID: {cidx}")
    conf = mol_h.GetConformer(cidx)
    torsionList = enumerateTorsions(mol_h)
    
    # Print dihedral angle for each torsion in degrees
    for torsion in torsionList:
        i, j, k, l = torsion
        dihedral_angle = rdMolTransforms.GetDihedralDeg(conf, i, j, k, l)
        print(f"Dihedral angle for torsion {torsion}: {dihedral_angle} degrees")
# Out:
# List of torsions: [(4, 0, 1, 2), (0, 1, 2, 3)]
# 0 C
# 1 C
# 2 C
# 3 N
# 4 H
# 5 H
# 6 H
# [(0, 1), (1, 2), (2, 3), (0, 4), (0, 5), (1, 6)]
# Conformer ID: 0
# Dihedral angle for torsion (4, 0, 1, 2): 0.00030952837989261476 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -82.15255498382817 degrees
# Conformer ID: 1
# Dihedral angle for torsion (4, 0, 1, 2): 179.99996990287673 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 88.344618009416 degrees
# Conformer ID: 2
# Dihedral angle for torsion (4, 0, 1, 2): 179.99959476621765 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 27.85439650215755 degrees
# Conformer ID: 3
# Dihedral angle for torsion (4, 0, 1, 2): 179.9999921860865 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 4.55167797858197 degrees
# Conformer ID: 4
# Dihedral angle for torsion (4, 0, 1, 2): 0.00020328605692602214 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 158.0509650208065 degrees
# Conformer ID: 5
# Dihedral angle for torsion (4, 0, 1, 2): -179.9999100963276 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -66.4554960247713 degrees
# Conformer ID: 6
# Dihedral angle for torsion (4, 0, 1, 2): 179.99981058570023 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -67.12530573880129 degrees
# Conformer ID: 7
# Dihedral angle for torsion (4, 0, 1, 2): -0.012201162566678901 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -122.90909832910737 degrees
# Conformer ID: 8
# Dihedral angle for torsion (4, 0, 1, 2): -179.99976094187488 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -86.94146384371575 degrees
# Conformer ID: 9
# Dihedral angle for torsion (4, 0, 1, 2): -179.99927122120127 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -165.8950464943535 degrees
# Conformer ID: 10
# Dihedral angle for torsion (4, 0, 1, 2): -0.00016527176622267755 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -120.30225401214463 degrees
# Conformer ID: 11
# Dihedral angle for torsion (4, 0, 1, 2): 179.97454361749897 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -20.58518504515921 degrees
# Conformer ID: 12
# Dihedral angle for torsion (4, 0, 1, 2): -2.006433311377512e-05 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 169.2435132652072 degrees
# Conformer ID: 13
# Dihedral angle for torsion (4, 0, 1, 2): 179.99967132745329 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -146.1857831554498 degrees
# Conformer ID: 14
# Dihedral angle for torsion (4, 0, 1, 2): 179.99922480129692 degrees
# Dihedral angle for torsion (0, 1, 2, 3):
degrees
# Dihedral angle for torsion (0, 1, 2, 3): -59.01664629799731 degrees
# Conformer ID: 95
# Dihedral angle for torsion (4, 0, 1, 2): 0.025568468656421327 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 174.96148910606465 degrees
# Conformer ID: 96
# Dihedral angle for torsion (4, 0, 1, 2): 179.99976595317358 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -30.984847524538228 degrees
# Conformer ID: 97
# Dihedral angle for torsion (4, 0, 1, 2): 179.99990806795347 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 42.960872916981856 degrees
# Conformer ID: 98
# Dihedral angle for torsion (4, 0, 1, 2): 0.0002732529259598173 degrees
# Dihedral angle for torsion (0, 1, 2, 3): -30.64099906887511 degrees
# Conformer ID: 99
# Dihedral angle for torsion (4, 0, 1, 2): -179.99996356443467 degrees
# Dihedral angle for torsion (0, 1, 2, 3): 53.296861256818055 degrees

# %% [markdown]
# ## Loading train dataset

# %%
df_train=pd.read_csv('./train.csv')
df_train_smiles=df_train["smiles"]
df_train_smiles.head(5)
print(len(df_train_smiles))
# Out:
# 6687

# %%
confs = [smi2conf_etkdg(s) for s in df_train_smiles]
max_confs=len(confs)

def style_selector(idx, s):
    conf = confs[idx]
    return MolTo3DView(conf, style=s).show()

interact(style_selector, 
         idx=ipywidgets.IntSlider(min=0,max=(max_confs-1), step=1),
         s=ipywidgets.Dropdown(
            options=['line', 'stick', 'sphere'],
            value='line',
            description='Style:'))
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=6686), Dropdown(description='Style:', options=…
# <function __main__.style_selector(idx, s)>

# %% [markdown]
# ## Loading test dataset

# %%
df_test=pd.read_csv('./test.csv')
df_test_smiles=df_test["smiles"]
df_test_smiles.head(5)
print([df_test_smiles])
print(len(df_test_smiles))
# Out:
# [0        O=C1C2C3CC1CCN23
# 1        CC1C2N=C3OCC3C12
# 2         OCC1OC1C(F)(F)F
# 3        N=C1OCC11C2CC1C2
# 4        C1OC11C=CCN2CC12
#               ...
# 738    CC1=NC(F)=CC(=O)N1
# 739     CC(=NO)C1(CC1)C#C
# 740      C#CC1(CN1)C1COC1
# 741       CC12NC1CC=C2C=O
# 742    CC1=NC2C3CC(O1)C23
# Name: smiles, Length: 743, dtype: object]
# 743

# %%
confs = [smi2conf_etkdg(s) for s in df_test_smiles]
max_confs=len(confs)

def style_selector(idx, s):
    conf = confs[idx]
    return MolTo3DView(conf, style=s).show()

interact(style_selector, 
         idx=ipywidgets.IntSlider(min=0,max=(max_confs-1), step=1),
         s=ipywidgets.Dropdown(
            options=['line', 'stick', 'sphere'],
            value='line',
            description='Style:'))
# Out:
# interactive(children=(IntSlider(value=0, description='idx', max=742), Dropdown(description='Style:', options=(…
# <function __main__.style_selector(idx, s)>

# %% [markdown]
# ## Checking a specific SMILES Using MMFF94s

# %%
def smi2conf(smiles):
    '''Convert SMILES to rdkit.Mol with 3D coordinates'''
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        mol = Chem.AddHs(mol)
        AllChem.EmbedMolecule(mol)
        AllChem.MMFFOptimizeMolecule(mol, maxIters=200, mmffVariant='MMFF94s')
        return mol
    else:
        return None

@interact
def smi2viewer(smi='OO'):
    try:
        conf = smi2conf(smi)
        return MolTo3DView(conf).show()
    except:
        return None
