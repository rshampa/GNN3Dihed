# %% [markdown]
# ## Know your libraries (KYL)

# %%
import sys
sys.path.append('../src')

import dataset, molecular_representation, config, utils, model
from dataset import QM9Dataset,LogSDataset,LogPDataset,FreeSolvDataset,ESOLDataset
import numpy as np
import pandas as pd
from utils import *
import torch
from scipy.stats import pearsonr
from tqdm import tqdm
from model import Autoencoder # Simply importing the autoencoder model module from the model.py file
from model import GNN3D,GNN3DAtnON,GNN3DAtnOFF,GNN3Dihed

import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import MolsToGridImage

import os
datadir="../data/esol/"
modeldir="./models_gnn3datnon_rmse/esol/"
dataset_name="esol"
# Create datadir and modeldir folders if they don't exist
if not os.path.exists(datadir):
    os.makedirs(datadir)
    
if not os.path.exists(modeldir):
    os.makedirs(modeldir)

import time
import datetime

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# ## Split your dataset (SYD)

# %%
# Load dataset from CSV
dataset = pd.read_csv(datadir+dataset_name+".csv")

# Split dataset into train and test
train_dataset, test_dataset = split_dataset(dataset, 0.9)

# Write train_dataset and test_dataset to CSV files
train_dataset.to_csv(datadir+"train.csv", index=False)
test_dataset.to_csv(datadir+"test.csv", index=False)

print("Train and test datasets saved successfully.")
# Out:
# Train and test datasets saved successfully.

# %% [markdown]
# ## Process your data (PYD)

# %%
train_samples = FreeSolvDataset(datadir+"train")
print(train_samples)
print("===================================")
test_samples = FreeSolvDataset(datadir+"test")
print(test_samples)
# Out:
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: FreeSolv
# Number of Molecules Loaded: 1015
# ===================================
# Loading dataset from folder
# Initializing Molecular Representation Generator
# Dataset Name: FreeSolv
# Number of Molecules Loaded: 113

# %% [markdown]
# ## Know your featues (KYF)

# %%
# Printing out the dimensions of all of these features with a description of what each feature is
print(f"Atomic Features: {(train_samples[0])[0].shape} - This represents the atomic features of the molecule")
print(f"Bond Features: {(train_samples[0])[1].shape} - This represents the bond features of the molecule")
print(f"Angle Features: {(train_samples[0])[2].shape} - This represents the angle features of the molecule")
print(f"Dihedral Features: {(train_samples[0])[3].shape} - This represents the dihedral features of the molecule")
print(f"Global Molecular Features: {(train_samples[0])[4].shape} - This represents the global molecular features of the molecule")
print(f"Bond Indices: {(train_samples[0])[5].shape} - This represents the bond indices of the molecule")
print(f"Angle Indices: {(train_samples[0])[6].shape} - This represents the angle indices of the molecule")
print(f"Dihedral Indices: {(train_samples[0])[7].shape} - This represents the dihedral indices of the molecule")
print(f"Target: {(train_samples[0])[8].shape} - This represents the target of the molecule")
# Out:
# Atomic Features: torch.Size([36, 154]) - This represents the atomic features of the molecule
# Bond Features: torch.Size([76, 10]) - This represents the bond features of the molecule
# Angle Features: torch.Size([130]) - This represents the angle features of the molecule
# Dihedral Features: torch.Size([174]) - This represents the dihedral features of the molecule
# Global Molecular Features: torch.Size([200]) - This represents the global molecular features of the molecule
# Bond Indices: torch.Size([76, 2]) - This represents the bond indices of the molecule
# Angle Indices: torch.Size([130, 2]) - This represents the angle indices of the molecule
# Dihedral Indices: torch.Size([174, 2]) - This represents the dihedral indices of the molecule
# Target: torch.Size([1]) - This represents the target of the molecule

# %% [markdown]
# ## Know your modules (KYM)

# %%
def train_gnn3d_vary_dataset_size(train_samples, min_samples=10, max_samples=45, divisions=3, n_epochs= 10, printstep=10, save_dir="./models/vary_train_size/", dataset_name="logs"):
    """Train GNN3D for varying training set size"""
    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)
   
    # Determine step size for each division
    sample_step_size = int((max_samples - min_samples) / divisions) + 1

    # Dictionary to store RMSE and MSE for each division
    gnn_rmse_dict = {}

    # Open a file to save the accumulated losses
    losses_file = os.path.join(save_dir, f"vary_size_gnn3d_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Training set size |\tRMSE Loss |\tMSE Loss\n")
    
        # Loop through divisions
        for division_i in range(divisions + 1):
            # Initialize training components for each division
            # Aond and bond autoencoders' dimensions to be changed for a new dataset
            atom_autoencoder = Autoencoder(154, 10).to(device)
            bond_autoencoder = Autoencoder(10, 3).to(device)
            mse_loss_fn = torch.nn.MSELoss()
            gnn3d = GNN3DAtnON(atomic_vector_size=10, bond_vector_size=3, number_of_molecular_features=200, number_of_targets=1).to(device)
            gnn_optimizer = torch.optim.Adam(gnn3d.parameters())

            for epoch_i in range(n_epochs):
                # Average losses initialization
                avg_rmse = 0
                avg_mse = 0

                # Current size of the training set for this division
                current_size = min_samples + sample_step_size * division_i

                # Initialize dictionary entry for current division
                gnn_rmse_dict["d" + str(current_size)] = {"avg_rmse": [], "avg_mse": []}

                # Training loop for current division
                for sample_i in tqdm(range(len(train_samples)), desc=f"Division {division_i + 1}/{divisions + 1}"):
                    if sample_i >= current_size:
                        break

                    molecule = train_samples[sample_i]
                    target = molecule[8].to(device)

                    input_representation = [
                        atom_autoencoder.encode(molecule[0].to(device)),
                        bond_autoencoder.encode(molecule[1].to(device)),
                        molecule[2].to(device),
                        molecule[3].to(device),
                        molecule[4].to(device),
                        molecule[5].to(device),
                        molecule[6].to(device),
                        molecule[7].to(device)
                    ]

                    # Forward pass
                    prediction = gnn3d(input_representation)

                    # Compute loss
                    loss = mse_loss_fn(prediction, target)

                    # Backward pass and optimization step
                    gnn_optimizer.zero_grad()
                    loss.backward()
                    gnn_optimizer.step()

                    # Update average RMSE and MSE
                    avg_rmse = (avg_rmse * sample_i + torch.sqrt(loss).item()) / (sample_i + 1)
                    avg_mse = (avg_mse * sample_i + loss.item()) / (sample_i + 1)
                    gnn_rmse_dict["d" + str(current_size)]["avg_rmse"].append(avg_rmse)
                    gnn_rmse_dict["d" + str(current_size)]["avg_mse"].append(avg_mse)

                    if (sample_i % printstep == 0):
                        print(f"Epoch: {epoch_i:>3} | Samples: {sample_i:>6}/{current_size:>3} | RMSE Loss: {avg_rmse:.4f} | MSE Loss: {avg_mse:.4f} | target: {target.item():.4f} | pred: {prediction.item():.4f}")
    
            # Save losses to a file
            f.write(f"{current_size}\t{avg_rmse}\t{avg_mse}\n")
        
        # Save model state after each division
        torch.save(gnn3d.state_dict(), f"{save_dir}gnn3d_{dataset_name}_div{current_size}.pth")

    return gnn_rmse_dict

# %%
gnn_rmse_dict= train_gnn3d_vary_dataset_size(train_samples, min_samples=100, max_samples=500, divisions=5, n_epochs= 10, printstep=32, save_dir=modeldir, dataset_name=dataset_name)
# Out:
# Division 1/6:   0%|▍                                                                                                                                   | 3/1015 [00:00<01
# Epoch:   9 | Samples:    384/505 | RMSE Loss: 0.4738 | MSE Loss: 0.3932 | target: -3.4990 | pred: -4.5464
# Division 6/6:  41%|█████████████████████████████████████████████████████▋                                                                            | 419/1015 [00:34<00:41, 14.53it/s]
# Epoch:   9 | Samples:    416/505 | RMSE Loss: 0.4661 | MSE Loss: 0.3837 | target: -1.6140 | pred: -2.0687
# Division 6/6:  44%|█████████████████████████████████████████████████████████▊                                                                        | 451/1015 [00:37<00:40, 14.05it/s]
# Epoch:   9 | Samples:    448/505 | RMSE Loss: 0.4680 | MSE Loss: 0.3821 | target: -4.5600 | pred: -4.3653
# Division 6/6:  47%|█████████████████████████████████████████████████████████████▎                                                                    | 479/1015 [00:39<00:44, 12.05it/s]
# Epoch:   9 | Samples:    480/505 | RMSE Loss: 0.4672 | MSE Loss: 0.3789 | target: -2.5100 | pred: -1.2093
# Division 6/6:  50%|████████████████████████████████████████████████████████████████▋                                                                 | 505/1015 [00:41<00:41, 12.21it/s]

# %%
# Plot all divisions on the same plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed

for key in gnn_rmse_dict.keys():
    plt.plot(gnn_rmse_dict[key]["avg_rmse"], label=f"dataset size = {key[1:]}")

plt.legend()
plt.title("GNN3D RMSE Loss for Different Dataset Sizes")
plt.xlabel("Training set size")
plt.ylabel("RMSE Loss")
plt.grid(True)
plt.tight_layout()

# Save the plot
plt.savefig(f"{modeldir}gnn3d_{dataset_name}_all_divisions.svg", format='svg')
plt.show()

# %%
def train_autoencoder_model(samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train Autoencoder: Atom and bond"""
    # Set the model in training mode
    atom_autoencoder.train()
    bond_autoencoder.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)

    # Lists to store losses
    avg_atom_rmse_losses = []
    avg_bond_rmse_losses = []

    for epoch_i in range(n_epochs):
        avg_atom_rmse_loss = 0
        avg_bond_rmse_loss = 0
        total_samples = 0
        
        for i, molecule in enumerate(samples):
            atom_features = molecule[0].to(device)
            bond_features = molecule[1].to(device)
            
            # Forward pass
            atom_features_reconstructed = atom_autoencoder(atom_features)
            bond_features_reconstructed = bond_autoencoder(bond_features)
            
            # Calculating loss
            atom_loss = mse_loss_fn(atom_features_reconstructed, atom_features)
            bond_loss = mse_loss_fn(bond_features_reconstructed, bond_features)
            
            # Backward pass and optimization step
            atom_optimizer.zero_grad()
            bond_optimizer.zero_grad()
            atom_loss.backward()
            bond_loss.backward()
            atom_optimizer.step()
            bond_optimizer.step()
            
            # Calculating average loss
            avg_atom_rmse_loss = (avg_atom_rmse_loss * total_samples + torch.sqrt(atom_loss).item()) / (total_samples + 1)
            avg_bond_rmse_loss = (avg_bond_rmse_loss * total_samples + torch.sqrt(bond_loss).item()) / (total_samples + 1)           
            total_samples += 1

            
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3}/{n_epochs} | Samples: {i:>6}/{len(samples)} | Atom RMSE Loss: {avg_atom_rmse_loss:.4f} | Bond RMSE Loss: {avg_bond_rmse_loss:.4f}")
        
        # Append average losses for the epoch to lists
        avg_atom_rmse_losses.append(avg_atom_rmse_loss)
        avg_bond_rmse_losses.append(avg_bond_rmse_loss)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"autoencoder_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch |\tAtom RMSE Loss |\tBond RMSE Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i}\t{avg_atom_rmse_losses[epoch_i]}\t{avg_bond_rmse_losses[epoch_i]}\n")

    # Save model state
    torch.save(atom_autoencoder.state_dict(), f"{save_dir}atom_autoencoder_{dataset_name}.pth")
    torch.save(bond_autoencoder.state_dict(), f"{save_dir}bond_autoencoder_{dataset_name}.pth")
    
    return avg_atom_rmse_losses, avg_bond_rmse_losses
    



def process_molecule(molecule, atom_autoencoder, bond_autoencoder):
    """Separate input features and target"""
    # Ensure molecule has at least 8 elements
    if len(molecule) < 8:
        return None, None
    
    target = molecule[8].to(device)  # Assuming target is the 9th element (index 8)
    # Assuming first 8 elements are molecule graph input features:
    # atomic_features, bond_features, angle_features, dihedral_features, 
    # global_molecular_features, bond_indices, angle_indices,  dihedral_indices    
    molecule_data = [mol_elem.to(device) for mol_elem in molecule[:8]]
    
    # Putting latent atomic and bond features through encoders
    molecule_data[0] = atom_autoencoder.encode(molecule_data[0])
    molecule_data[1] = bond_autoencoder.encode(molecule_data[1])
    
    return molecule_data, target




def train_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder, n_epochs=10, printstep=10, save_dir="./models/", dataset_name="logs"):
    """Train GNN3D"""
    # Set the model in training mode
    gnn3d.train()

    # Create the directory if it does not exist
    os.makedirs(save_dir, exist_ok=True)
   
    # Lists to store losses
    avg_rmse_losses_train = []
    avg_mse_losses_train = []
    avg_rmse_losses_val = []
    avg_mse_losses_val = []

    # Start timing
    start_time = time.time()
    
    for epoch_i in range(n_epochs):
        # Training phase
        avg_rmse_loss_train = 0
        avg_mse_loss_train = 0
        total_samples_train = 0
    
        for i in tqdm(range(len(train_part_samples)), desc='Training samples'):
            molecule_data, target = process_molecule(train_part_samples[i], atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
        
            prediction = gnn3d(molecule_data)
            loss = mse_loss_fn(prediction, target)
        
            gnn_optimizer.zero_grad()
            loss.backward()
            gnn_optimizer.step()
        
            avg_rmse_loss_train = (avg_rmse_loss_train * total_samples_train + torch.sqrt(loss).item()) / (total_samples_train + 1)
            avg_mse_loss_train = (avg_mse_loss_train * total_samples_train + loss.item()) / (total_samples_train + 1)
            total_samples_train += 1
        
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3} | Train Samples: {i:>6}/{len(train_part_samples)} | RMSE Loss: {avg_rmse_loss_train:.4f} | MSE Loss: {avg_mse_loss_train:.4f}")
    
        # Validation phase
        avg_rmse_loss_val = 0
        avg_mse_loss_val = 0
        total_samples_val = 0
    
        for i in tqdm(range(len(val_samples)), desc='Validation samples'):
            molecule_data, target = process_molecule(val_samples[i], atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
        
            prediction = gnn3d(molecule_data)
            loss = mse_loss_fn(prediction, target)
        
            avg_rmse_loss_val = (avg_rmse_loss_val * total_samples_val + torch.sqrt(loss).item()) / (total_samples_val + 1)
            avg_mse_loss_val = (avg_mse_loss_val * total_samples_val + loss.item()) / (total_samples_val + 1)
            total_samples_val += 1
        
            if (i % printstep == 0):
                print(f"Epoch: {epoch_i:>3} | Val Samples: {i:>6}/{len(val_samples)} | RMSE Loss: {avg_rmse_loss_val:.4f} | MSE Loss: {avg_mse_loss_val:.4f}")
    
        # Append average losses for the epoch to lists
        avg_rmse_losses_train.append(avg_rmse_loss_train)
        avg_mse_losses_train.append(avg_mse_loss_train)
        avg_rmse_losses_val.append(avg_rmse_loss_val)
        avg_mse_losses_val.append(avg_mse_loss_val)
                
    # Save the accumulated losses to a file
    losses_file = os.path.join(save_dir, f"gnn3d_losses_{dataset_name}.txt")
    with open(losses_file, 'w') as f:
        f.write(f"Epoch |\tRMSE Train Loss |\tMSE Train Loss |\tRMSE Val Loss |\tMSE Val Loss\n")
        for epoch_i in range(n_epochs):
            f.write(f"{epoch_i}\t{avg_rmse_losses_train[epoch_i]}\t{avg_mse_losses_train[epoch_i]}\t{avg_rmse_losses_val[epoch_i]}\t{avg_mse_losses_val[epoch_i]}\n")

    # Save model state
    torch.save(gnn3d.state_dict(), f"{save_dir}gnn3d_{dataset_name}.pth")

    # End timing
    end_time = time.time()
    
    actual_time = end_time - start_time

    actual_time_td = datetime.timedelta(seconds=actual_time)
    hours = actual_time_td.seconds // 3600
    minutes = (actual_time_td.seconds // 60) % 60
    seconds = actual_time_td.seconds % 60
    actual_time_str = f"{hours} hours, {minutes} minutes, {seconds} seconds"
    
    print(f"Time taken for training: {actual_time_str}")
    
    return avg_rmse_losses_train, avg_mse_losses_train, avg_rmse_losses_val, avg_mse_losses_val




def evaluate_gnn3d_model(gnn3d, samples, atom_autoencoder, bond_autoencoder):
    """Evaluate GNN3D"""
    # Set the model in evaluation mode
    gnn3d.eval()

    # List to store predictions
    predictions = []
    targets = []
    
    avg_rmse_loss = 0
    avg_mse_loss = 0
    total_samples = 0
    
    # Start timing
    start_time = time.time()
    
    with torch.no_grad():
        for i, molecule in enumerate(samples):
            molecule_data, target = process_molecule(molecule, atom_autoencoder, bond_autoencoder)
            if molecule_data is None:
                continue
            
            # Forward pass
            prediction = gnn3d(molecule_data)

            # Extract target, prediction
            target_value = target.item()
            prediction_value = prediction.item()

            # For every test samples
            #print(f"Target: {target.item():.4f} | Prediction: {prediction.item():.4f}")
    
            # Store prediction
            predictions.append(prediction_value)
            targets.append(target_value)
                        
            # Calculating loss
            loss = mse_loss_fn(prediction, target)
                     
            # Accumulate losses
            avg_rmse_loss += (torch.sqrt(loss).item())
            avg_mse_loss += loss.item()
            total_samples += 1
    
    # Calculate average losses
    avg_rmse_loss /= total_samples
    avg_mse_loss /= total_samples

    # End timing
    end_time = time.time()

    actual_time = end_time - start_time

    actual_time_td = datetime.timedelta(seconds=actual_time)
    hours = actual_time_td.seconds // 3600
    minutes = (actual_time_td.seconds // 60) % 60
    seconds = actual_time_td.seconds % 60
    actual_time_str = f"{hours} hours, {minutes} minutes, {seconds} seconds"    
    
    print(f"Evaluation Results:")
    print(f"RMSE Loss: {avg_rmse_loss:.4f}")
    print(f"MSE Loss: {avg_mse_loss:.4f}")
    print(f"Time taken for evaluation: {actual_time_str}")
    
    return predictions, targets

# %% [markdown]
# ## Training

# %% [markdown]
# ### Autoencoder training

# %%
atom_autoencoder = Autoencoder(154, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
atom_optimizer = torch.optim.Adam(atom_autoencoder.parameters())
bond_optimizer = torch.optim.Adam(bond_autoencoder.parameters())

atom_losses, bond_losses = train_autoencoder_model(train_samples, atom_autoencoder, bond_autoencoder, n_epochs=25, printstep=32, save_dir=modeldir, dataset_name=dataset_name)
# Out:
# Epoch:   0/25 | Samples:      0/1015 | Atom RMSE Loss: 0.2163 | Bond RMSE Loss: 0.5232
# Epoch:   0/25 | Samples:     32/1015 | Atom RMSE Loss: 0.1834 | Bond RMSE Loss: 0.4689
# Epoch:   0/25 | Samples:     64/1015 | Atom RMSE Loss: 0.1571 | Bond RMSE Loss: 0.4559
# Epoch:   0/25 | Samples:     96/1015 | Atom RMSE Loss: 0.1478 | Bond RMSE Loss: 0.4348
# Epoch:   0/25 | Samples:    128/1015 | Atom RMSE Loss: 0.1411 | Bond RMSE Loss: 0.3962
# Epoch:   0/25 | Samples:    160/1015 | Atom RMSE Loss: 0.1334 | Bond RMSE Loss: 0.3739
# Epoch:   0/25 | Samples:    192/1015 | Atom RMSE Loss: 0.1236 | Bond RMSE Loss: 0.3546
# Epoch:   0/25 | Samples:    224/1015 | Atom RMSE Loss: 0.1155 | Bond RMSE Loss: 0.3426
# Epoch:   0/25 | Samples:    256/1015 | Atom RMSE Loss: 0.1091 | Bond RMSE Loss: 0.3349
# Epoch:   0/25 | Samples:    288/1015 | Atom RMSE Loss: 0.1037 | Bond RMSE Loss: 0.3270
# Epoch:   0/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0991 | Bond RMSE Loss: 0.3181
# Epoch:   0/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0952 | Bond RMSE Loss: 0.3091
# Epoch:   0/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0917 | Bond RMSE Loss: 0.2988
# Epoch:   0/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0890 | Bond RMSE Loss: 0.2883
# Epoch:   0/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0861 | Bond RMSE Loss: 0.2775
# Epoch:   0/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0838 | Bond RMSE Loss: 0.2666
# Epoch:   0/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0818 | Bond RMSE Loss: 0.2576
# Epoch:   0/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0801 | Bond RMSE Loss: 0.2490
# Epoch:   0/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0784 | Bond RMSE Loss: 0.2418
# Epoch:   0/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0769 | Bond RMSE Loss: 0.2342
# Epoch:   0/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0756 | Bond RMSE Loss: 0.2280
# Epoch:   0/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0742 | Bond RMSE Loss: 0.2227
# Epoch:   0/25 | Samples:    704/1015 | Atom RMSE Loss: 0.
25 | Samples:    800/1015 | Atom RMSE Loss: 0.0278 | Bond RMSE Loss: 0.0747
# Epoch:   3/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0278 | Bond RMSE Loss: 0.0748
# Epoch:   3/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0277 | Bond RMSE Loss: 0.0743
# Epoch:   3/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0276 | Bond RMSE Loss: 0.0736
# Epoch:   3/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0276 | Bond RMSE Loss: 0.0725
# Epoch:   3/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0275 | Bond RMSE Loss: 0.0721
# Epoch:   3/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0275 | Bond RMSE Loss: 0.0716
# Epoch:   4/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0814
# Epoch:   4/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0257 | Bond RMSE Loss: 0.0452
# Epoch:   4/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0254 | Bond RMSE Loss: 0.0477
# Epoch:   4/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0259 | Bond RMSE Loss: 0.0489
# Epoch:   4/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0260 | Bond RMSE Loss: 0.0514
# Epoch:   4/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0515
# Epoch:   4/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0509
# Epoch:   4/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0262 | Bond RMSE Loss: 0.0496
# Epoch:   4/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0503
# Epoch:   4/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0509
# Epoch:   4/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0260 | Bond RMSE Loss: 0.0501
# Epoch:   4/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0259 | Bond RMSE Loss: 0.0502
# Epoch:   4/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0259 | Bond RMSE Loss: 0.0505
# Epoch:   4/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0258 | Bond RMSE Loss: 0.0504
# Epoch:   4/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0257 | Bond RMSE Loss: 0.0503
# Epoch:   4/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0256 | Bond RMSE Loss: 0.0499
# Epoch:   4/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0256 | Bond RMSE Loss: 0.0500
# Epoch:   4/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0256 | Bond RMSE Loss: 0.0497
# Epoch:   4/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0256 | Bond RMSE Loss: 0.0498
# Epoch:   4/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0255 | Bond RMSE Loss: 0.0494
# Epoch:   4/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0256 | Bond RMSE Loss: 0.0495
# Epoch:   4/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0257 | Bond RMSE Loss: 0.0494
# Epoch:   4/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0258 | Bond RMSE Loss: 0.0490
# Epoch:   4/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0260 | Bond RMSE Loss: 0.0483
# Epoch:   4/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0481
# Epoch:   4/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0482
# Epoch:   4/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0483
# Epoch:   4/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0481
# Epoch:   4/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0475
# Epoch:   4/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0468
# Epoch:   4/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0465
# Epoch:   4/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0264 | Bond RMSE Loss: 0.0462
# Epoch:   5/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0246 | Bond RMSE Loss: 0.0427
# Epoch:   5/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0271 | Bond RMSE Loss: 0.0265
# Epoch:   5/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0267 | Bond RMSE Loss: 0.0284
# Epoch:   5/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0271 | Bond RMSE Loss: 0.0316
# Epoch:   5/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0270 | Bond RMSE Loss: 0.0366
# Epoch:   5/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0266 | Bond RMSE Loss: 0.0383
# Epoch:   5/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0264 | Bond RMSE Loss: 0.0378
# Epoch:   5/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0263 | Bond RMSE Loss: 0.0361
# Epoch:   5/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0363
# Epoch:   5/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0261 | Bond RMSE Loss: 0.0364
# Epoch:   5/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0259 | Bond RMSE Loss: 0.0358
# Epoch:   5/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0258 | Bond RMSE Loss: 0.0358
# Epoch:   5/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0257 | Bond RMSE Loss: 0.0362
# Epoch:   5/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0256 | Bond RMSE Loss: 0.0361
# Epoch:   5/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0255 | Bond RMSE Loss: 0.0360
# Epoch:   5/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0254 | Bond RMSE Loss: 0.0358
# Epoch:   5/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0253 | Bond RMSE Loss: 0.0359
# Epoch:   5/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0253 | Bond RMSE Loss: 0.0356
# Epoch:   5/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0253 | Bond RMSE Loss: 0.0357
# Epoch:   5/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0356
# Epoch:   5/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0360
# Epoch:   5/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0361
# Epoch:   5/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0359
# Epoch:   5/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0253 | Bond RMSE Loss: 0.0355
# Epoch:   5/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0253 | Bond RMSE Loss: 0.0353
# Epoch:   5/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0356
# Epoch:   5/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0359
# Epoch:   5/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0359
# Epoch:   5/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0354
# Epoch:   5/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0349
# Epoch:   5/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0347
# Epoch:   5/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0251 | Bond RMSE Loss: 0.0346
# Epoch:   6/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0231 | Bond RMSE Loss: 0.0285
# Epoch:   6/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0250 | Bond RMSE Loss: 0.0205
# Epoch:   6/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0218
# Epoch:   6/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0250 | Bond RMSE Loss: 0.0249
# Epoch:   6/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.0257
# Epoch:   6/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0254 | Bond RMSE Loss: 0.0257
# Epoch:   6/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0254 | Bond RMSE Loss: 0.0262
# Epoch:   6/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0255 | Bond RMSE Loss: 0.0254
# Epoch:   6/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0254 | Bond RMSE Loss: 0.0260
# Epoch:   6/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0254 | Bond RMSE Loss: 0.0265
# Epoch:   6/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0252 | Bond RMSE Loss: 0.
25 | Samples:     96/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0086
# Epoch:  16/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0091
# Epoch:  16/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0089
# Epoch:  16/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0246 | Bond RMSE Loss: 0.0103
# Epoch:  16/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0246 | Bond RMSE Loss: 0.0101
# Epoch:  16/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0103
# Epoch:  16/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0106
# Epoch:  16/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0106
# Epoch:  16/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0243 | Bond RMSE Loss: 0.0109
# Epoch:  16/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0243 | Bond RMSE Loss: 0.0113
# Epoch:  16/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0242 | Bond RMSE Loss: 0.0113
# Epoch:  16/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0115
# Epoch:  16/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0115
# Epoch:  16/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0121
# Epoch:  16/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0121
# Epoch:  16/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0124
# Epoch:  16/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0126
# Epoch:  16/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0129
# Epoch:  16/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0129
# Epoch:  16/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0128
# Epoch:  16/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0127
# Epoch:  16/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0124
# Epoch:  16/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0127
# Epoch:  16/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0132
# Epoch:  16/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0136
# Epoch:  16/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0135
# Epoch:  16/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0133
# Epoch:  16/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0133
# Epoch:  16/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0134
# Epoch:  17/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0227 | Bond RMSE Loss: 0.0083
# Epoch:  17/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0071
# Epoch:  17/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0064
# Epoch:  17/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0083
# Epoch:  17/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0090
# Epoch:  17/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0088
# Epoch:  17/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0102
# ...
# Epoch:  19/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0116
# Epoch:  19/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0115
# Epoch:  19/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0116
# Epoch:  19/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0120
# Epoch:  19/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0120
# Epoch:  19/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0120
# Epoch:  19/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0120
# Epoch:  19/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0126
# Epoch:  19/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0124
# Epoch:  19/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0124
# Epoch:  19/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0125
# Epoch:  19/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0127
# Epoch:  19/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0127
# Epoch:  19/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0125
# Epoch:  19/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0124
# Epoch:  19/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0121
# Epoch:  19/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0123
# Epoch:  19/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0127
# Epoch:  19/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0131
# Epoch:  19/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0129
# Epoch:  19/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0127
# Epoch:  19/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0126
# Epoch:  19/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0127
# Epoch:  20/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0229 | Bond RMSE Loss: 0.0083
# Epoch:  20/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0242 | Bond RMSE Loss: 0.0066
# Epoch:  20/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0059
# Epoch:  20/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0076
# Epoch:  20/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0081
# Epoch:  20/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0080
# Epoch:  20/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0093
# Epoch:  20/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0096
# Epoch:  20/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0107
# Epoch:  20/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0112
# Epoch:  20/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0112
# Epoch:  20/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0113
# Epoch:  20/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0117
# Epoch:  20/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0117
# Epoch:  20/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0116
# Epoch:  20/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0115
# Epoch:  20/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0121
# Epoch:  20/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0119
# Epoch:  20/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0119
# Epoch:  20/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0120
# Epoch:  20/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0123
# Epoch:  20/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0123
# Epoch:  20/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0121
# Epoch:  20/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0243 | Bond RMSE Loss: 0.0120
# Epoch:  20/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0117
# Epoch:  20/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0120
# Epoch:  20/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0124
# Epoch:  20/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0128
# Epoch:  20/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0127
# Epoch:  20/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0125
# Epoch:  20/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0245 | Bond RMSE Loss: 0.0125
# Epoch:  20/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0125
# Epoch:  21/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0228 | Bond RMSE Loss: 0.0085
# Epoch:  21/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0064
# Epoch:  21/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0058
# Epoch:  21/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0074
# Epoch:  21/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0079
# Epoch:  21/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0078
# Epoch:  21/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0090
# Epoch:  21/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0091
# Epoch:  21/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0094
# Epoch:  21/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0096
# Epoch:  21/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0096
# Epoch:  21/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0098
# Epoch:  21/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0102
# Epoch:  21/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0103
# Epoch:  21/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0104
# Epoch:  21/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0105
# Epoch:  21/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0112
# Epoch:  21/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0111
# Epoch:  21/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0112
# Epoch:  21/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0113
# Epoch:  21/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0116
# Epoch:  21/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0116
# Epoch:  21/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0114
# Epoch:  21/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0114
# Epoch:  21/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0111
# Epoch:  21/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0114
# Epoch:  21/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0119
# Epoch:  21/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0123
# Epoch:  21/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0122
# Epoch:  21/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0120
# Epoch:  21/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0121
# Epoch:  21/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0121
# Epoch:  22/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0228 | Bond RMSE Loss: 0.0085
# Epoch:  22/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0062
# Epoch:  22/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0057
# Epoch:  22/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0071
# Epoch:  22/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0076
# Epoch:  22/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0075
# Epoch:  22/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0087
# Epoch:  22/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0085
# Epoch:  22/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0088
# Epoch:  22/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0090
# Epoch:  22/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0090
# Epoch:  22/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0092
# Epoch:  22/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0096
# Epoch:  22/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0096
# Epoch:  22/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0097
# Epoch:  22/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0096
# Epoch:  22/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0102
# Epoch:  22/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0101
# Epoch:  22/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0101
# Epoch:  22/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0103
# Epoch:  22/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0106
# Epoch:  22/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0107
# Epoch:  22/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0107
# Epoch:  22/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0107
# Epoch:  22/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0105
# Epoch:  22/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0107
# Epoch:  22/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0234 | Bond RMSE Loss: 0.0112
# Epoch:  22/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0117
# Epoch:  22/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0116
# Epoch:  22/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0114
# Epoch:  22/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0115
# Epoch:  22/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0116
# Epoch:  23/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0090
# Epoch:  23/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0246 | Bond RMSE Loss: 0.0062
# Epoch:  23/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0242 | Bond RMSE Loss: 0.0057
# Epoch:  23/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0071
# Epoch:  23/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0075
# Epoch:  23/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0074
# Epoch:  23/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0085
# Epoch:  23/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0082
# Epoch:  23/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0086
# Epoch:  23/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0088
# Epoch:  23/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0088
# Epoch:  23/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0090
# Epoch:  23/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0093
# Epoch:  23/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0094
# Epoch:  23/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0094
# Epoch:  23/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0093
# Epoch:  23/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0098
# Epoch:  23/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0097
# Epoch:  23/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0098
# Epoch:  23/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0100
# Epoch:  23/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0103
# Epoch:  23/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0105
# Epoch:  23/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0105
# Epoch:  23/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0105
# Epoch:  23/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0103
# Epoch:  23/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0106
# Epoch:  23/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0111
# Epoch:  23/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0115
# Epoch:  23/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0114
# Epoch:  23/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0112
# Epoch:  23/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0113
# Epoch:  23/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0114
# Epoch:  24/25 | Samples:      0/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0093
# Epoch:  24/25 | Samples:     32/1015 | Atom RMSE Loss: 0.0247 | Bond RMSE Loss: 0.0062
# Epoch:  24/25 | Samples:     64/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0057
# Epoch:  24/25 | Samples:     96/1015 | Atom RMSE Loss: 0.0242 | Bond RMSE Loss: 0.0071
# Epoch:  24/25 | Samples:    128/1015 | Atom RMSE Loss: 0.0244 | Bond RMSE Loss: 0.0075
# Epoch:  24/25 | Samples:    160/1015 | Atom RMSE Loss: 0.0242 | Bond RMSE Loss: 0.0074
# Epoch:  24/25 | Samples:    192/1015 | Atom RMSE Loss: 0.0242 | Bond RMSE Loss: 0.0083
# Epoch:  24/25 | Samples:    224/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0080
# Epoch:  24/25 | Samples:    256/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0084
# Epoch:  24/25 | Samples:    288/1015 | Atom RMSE Loss: 0.0241 | Bond RMSE Loss: 0.0086
# Epoch:  24/25 | Samples:    320/1015 | Atom RMSE Loss: 0.0240 | Bond RMSE Loss: 0.0085
# Epoch:  24/25 | Samples:    352/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0087
# Epoch:  24/25 | Samples:    384/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0090
# Epoch:  24/25 | Samples:    416/1015 | Atom RMSE Loss: 0.0239 | Bond RMSE Loss: 0.0090
# Epoch:  24/25 | Samples:    448/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0091
# Epoch:  24/25 | Samples:    480/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0090
# Epoch:  24/25 | Samples:    512/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0094
# Epoch:  24/25 | Samples:    544/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0093
# Epoch:  24/25 | Samples:    576/1015 | Atom RMSE Loss: 0.0238 | Bond RMSE Loss: 0.0093
# Epoch:  24/25 | Samples:    608/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0096
# Epoch:  24/25 | Samples:    640/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0099
# Epoch:  24/25 | Samples:    672/1015 | Atom RMSE Loss: 0.0237 | Bond RMSE Loss: 0.0100
# Epoch:  24/25 | Samples:    704/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0100
# Epoch:  24/25 | Samples:    736/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0101
# Epoch:  24/25 | Samples:    768/1015 | Atom RMSE Loss: 0.0236 | Bond RMSE Loss: 0.0098
# Epoch:  24/25 | Samples:    800/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0100
# Epoch:  24/25 | Samples:    832/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0104
# Epoch:  24/25 | Samples:    864/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0107
# Epoch:  24/25 | Samples:    896/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0106
# Epoch:  24/25 | Samples:    928/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0104
# Epoch:  24/25 | Samples:    960/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0104
# Epoch:  24/25 | Samples:    992/1015 | Atom RMSE Loss: 0.0235 | Bond RMSE Loss: 0.0105

# %%
# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Atom RMSE Loss')
#plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Avg. Bond RMSE Loss')
plt.title(f"Atom Autoencoder Training Losses for {dataset_name}")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}atom_autoencoder_losses_{dataset_name}.png")
plt.show()

# Plotting the losses (optional)
plt.figure(figsize=(10, 6))
#plt.plot(range(1, len(atom_losses)+1), atom_losses, marker='o', linestyle='-', color='b', label='Avg. Atom RMSE Loss')
plt.plot(range(1, len(bond_losses)+1), bond_losses, marker='o', linestyle='-', color='r', label='Bond RMSE Loss')
plt.title(f"Bond Autoencoder Training Losses for {dataset_name}")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}bond_autoencoder_losses_{dataset_name}.png")
plt.show()

# %% [markdown]
# ### GNN3D training

# %%
from sklearn.model_selection import train_test_split

train_part_samples, val_samples = train_test_split(train_samples, test_size=0.1, random_state=42)

# %%
atom_autoencoder = Autoencoder(154, 10).to(device)
bond_autoencoder = Autoencoder(10, 3).to(device)
mse_loss_fn = torch.nn.MSELoss()
gnn3d = GNN3DAtnON(atomic_vector_size=10, bond_vector_size=3, number_of_molecular_features=200, number_of_targets=1).to(device)
gnn_optimizer = torch.optim.Adam(gnn3d.parameters())
rmse_losses_train, mse_losses_train, rmse_losses_val, mse_losses_val = train_gnn3d_model(gnn3d, train_samples, atom_autoencoder, bond_autoencoder, n_epochs=25, printstep=32, save_dir=modeldir, dataset_name=dataset_name)
# Out:
# Training samples:   0%|▍                                                                                                                                | 3/913 [00:00<01:34,  9.65it/s]
# Epoch:   0 | Train Samples:      0/913 | RMSE Loss: 5.6906 | MSE Loss: 32.3827
# Training samples:   4%|████▉                                                                                                                           | 35/913 [00:02<01:14, 11.78it/s]
# Epoch:   0 | Train Samples:     32/913 | RMSE Loss: 2.3614 | MSE Loss: 8.2561
# Training samples:   7%|█████████▎                                                                                                                      | 66/913 [00
84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▏                   | 771/913 [01:01<00:09, 14.71it/s]
# Epoch:  24 | Train Samples:    768/913 | RMSE Loss: 0.3679 | MSE Loss: 0.2322
# Training samples:  88%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▋               | 803/913 [01:04<00:07, 14.46it/s]
# Epoch:  24 | Train Samples:    800/913 | RMSE Loss: 0.3657 | MSE Loss: 0.2301
# Training samples:  91%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏          | 835/913 [01:06<00:05, 14.53it/s]
# Epoch:  24 | Train Samples:    832/913 | RMSE Loss: 0.3639 | MSE Loss: 0.2288
# Training samples:  95%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌      | 867/913 [01:09<00:03, 12.34it/s]
# Epoch:  24 | Train Samples:    864/913 | RMSE Loss: 0.3662 | MSE Loss: 0.2345
# Training samples:  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 900/913 [01:12<00:01, 11.11it/s]
# Epoch:  24 | Train Samples:    896/913 | RMSE Loss: 0.3634 | MSE Loss: 0.2306
# Training samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 913/913 [01:12<00:00, 12.53it/s]
# Validation samples:   5%|██████▏                                                                                                                        | 5/102 [00:00<00:02, 39.17it/s]
# Epoch:  24 | Val Samples:      0/102 | RMSE Loss: 0.3235 | MSE Loss: 0.1046
# Validation samples:  36%|█████████████████████████████████████████████▋                                                                                | 37/102 [00:01<00:02, 32.07it/s]
# Epoch:  24 | Val Samples:     32/102 | RMSE Loss: 0.5727 | MSE Loss: 0.4973
# Validation samples:  68%|█████████████████████████████████████████████████████████████████████████████████████▏                                        | 69/102 [00:02<00:00, 34.70it/s]
# Epoch:  24 | Val Samples:     64/102 | RMSE Loss: 0.5481 | MSE Loss: 0.4708
# Validation samples: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 102/102 [00:02<00:00, 34.35it/s]
# Epoch:  24 | Val Samples:     96/102 | RMSE Loss: 0.5614 | MSE Loss: 0.5103
# Time taken for training: 0 hours, 31 minutes, 23 seconds

# %%
# Assuming rmse_losses is the list of RMSE losses obtained from training
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(rmse_losses_train)+1), rmse_losses_train, marker='o', linestyle='-', color='b', label='Train RMSE Loss')
plt.plot(range(1, len(rmse_losses_val)+1), rmse_losses_val, marker='x', linestyle='-', color='r', label='Validation RMSE Loss')
plt.title(f"GNN3D Training Losses for {dataset_name}")
plt.xlabel("Epoch")
plt.ylabel("RMSE Loss")
plt.legend()
plt.grid(True)
plt.savefig(f"{modeldir}gnn3d_rmse_losses_{dataset_name}.png")
plt.show()

# %% [markdown]
# ## Testing

# %%
predictions, targets = evaluate_gnn3d_model(gnn3d, test_samples, atom_autoencoder, bond_autoencoder)
# Out:
# Evaluation Results:
# RMSE Loss: 0.5377
# MSE Loss: 0.4830
# Time taken for evaluation: 0 hours, 0 minutes, 2 seconds

# %% [markdown]
# ## Know your correlations (KYC)

# %%
# Calculate R^2
def calculate_r_squared(predictions, targets):
    ss_tot = np.sum((targets - np.mean(targets))**2)
    ss_res = np.sum((targets - predictions)**2)
    r_squared = 1 - (ss_res / ss_tot)
    return r_squared

# Convert lists to NumPy arrays
predictions = np.array(predictions)
targets = np.array(targets)

# Calculate Pearson correlation coefficient
corr, _ = pearsonr(predictions, targets)

print(f"Pearson Correlation Coefficient: {corr:.4f}")

r_squared = calculate_r_squared(predictions, targets)
print(f"Coefficient of Determination R^2: {r_squared:.4f}")

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(targets, predictions, color='blue', alpha=0.5)
plt.plot(targets, targets, color='red', linestyle='-', linewidth=2)  # Plot y=x line
plt.text(np.min(targets), np.max(predictions), f"Pearson Correlation: {corr:.4f}", fontsize=12, verticalalignment='top')
plt.title('Scatter Plot of Predictions vs Targets')
plt.xlabel('Targets')
plt.ylabel('Predictions')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Pearson Correlation Coefficient: 0.9441
# Coefficient of Determination R^2: 0.8772

# %% [markdown]
# ## Know your molecules and true/prediction (Be warned if there is skipped molecule from test_samples! No skip -> correct structure!)

# %%
print(f"Loaded train samples: {len(train_samples)}")
print(f"Loaded test samples: {len(test_samples)}")
print(f"Total (train+test): {len(train_samples) + len(test_samples)}" )
print(f"Total from dataset: {len(dataset)}")
print(f"80% of dataset: {int(0.8*len(dataset))}")
print(f"20% of dataset: {int(0.2*len(dataset))}")
print(f"NOT Skipped molecule, therefore following output of next cell is correct!")
# Out:
# Loaded train samples: 1015
# Loaded test samples: 113
# Total (train+test): 1128
# Total from dataset: 1128
# 80% of dataset: 902
# 20% of dataset: 225
# NOT Skipped molecule, therefore following output of next cell is correct!

# %%
# Load test_samples from CSV
test_dataset = pd.read_csv(datadir+"test.csv")
molecules = test_dataset['smiles'].apply(lambda x: Chem.MolFromSmiles(x)) 

y_true = [targets[i] for i in range(len(test_samples))]
y_pred = [predictions[i] for i in range(len(test_samples))]

legends = [f"y_true/y_pred = {y_true[i]:.2f}/{y_pred[i]:.2f}" for i in range(len(test_samples))]
MolsToGridImage(molecules, molsPerRow=5, maxMols=100,legends=legends)
# Out:
# /Users/shampa/software/anaconda3/envs/py312/lib/python3.12/site-packages/rdkit/Chem/Draw/IPythonConsole.py:261: UserWarning: Truncating the list of molecules to be displayed to 100. Change the maxMols value to display more.
#   warnings.warn(

# %%
df = pd.read_csv(datadir+"test.csv")      #Reading logS: y_true dataframe
df['preds'] = predictions
df
# Out:
#                                                 smiles  logSolubility  \
# 0          CCCCN(CC)c1c(cc(cc1N(=O)=O)C(F)(F)F)N(=O)=O         -5.530
# 1    CC1OC(CC(O)C1O)OC2C(O)CC(OC2C)OC8C(O)CC(OC7CCC...         -5.293
# 2                                                CCCCO          0.000
# 3                                     CCCCCCCCC(=O)OCC         -3.800
# 4                             CON(C)C(=O)Nc1ccc(Cl)cc1         -2.570
# ..                                                 ...            ...
# 108                   c1ccc2c(c1)c3cccc4ccc5cccc2c5c43         -7.800
# 109                 CN(C)C(=O)Nc2ccc(Oc1ccc(Cl)cc1)cc2         -4.890
# 110                                         O=Cc1ccco1         -0.100
# 111                                         CC(C)C(C)C         -3.650
# 112                            CCSC(=O)N(CC(C)C)CC(C)C         -3.680
#
#         preds
# 0   -6.516924
# 1   -5.008438
# 2   -0.035639
# 3   -3.981912
# 4   -2.821753
# ..        ...
# 108 -8.412110
# 109 -5.072530
# 110 -0.540455
# 111 -3.681593
# 112 -3.895309
#
# [113 rows x 3 columns]

# %% [markdown]
# ## Future task: What is so unique about dihedral angles?
